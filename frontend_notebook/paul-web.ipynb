# %% [markdown]
# # Data Visualization with Plotly Demo
#
# ## Introduction to Jupyter Notebook
# Jupyter Notebooks are a staple in any data scientist's toolkit. It is a free, open source, interactive data science environment that can function as both an IDE and a visualisation tool. A Jupyter Notebook is a single document where you can run code, display the output and add equations and explainations. Each notebook is a `.ipynb` file, which is a text file that describes the content of the notebook in JSON format.
#
# Each Jupter Notebook contains a kernal that can be thought of as a "computational engine" that executes the code within the notebook. Notebooks are made up of a number of cells. For example, this piece of text you are reading resides in the first cell of this notebook. They can be markdown cells that display text in-place or code cells. When a code cell is run, the output is displayed below the cell. The order in which cells are run matters! Cells containing functions or variables have to be run before those same functions or variables can be called from a subsequent cell.
#
# How to use a Jupyter Notebook:
# - To run a cell, either click the arrow to the left of the cell or press `ctrl + Enter` after selecting the cell. When a cell is run, a number will appear in square brackets (e.g. [1]) telling you the order in which each cell is run.
# - To interrupt a cell while it is running, press the button with the black square in the toolbar at the top
# - To restart the kernal, right-click `kernel` and choose from the list of restart options available
#
#
# ## Introduction to Plotly
#
# Pandas is an open source library providing data structure and data analysis tools for the Python language. Plotly is another open source that allows you to put together high quality graphs to faciliate the visualisation of the data. Plotly Dash (written on top of Plotly.js and React.js) allows one to quickly build data apps that are rendered in the browser.
#
# This notebook contains examples of how each of these libraries can be leveraged to analyse and visualise data. For more information, please check out the official documentation listed below.
#
# #### Further Documentation
# https://pandas.pydata.org/docs/ \
# https://plot.ly/python/ \
# https://dash.plotly.com/introduction

# %% [markdown]
# ## Setting Up
#
# You can install the libraries using pip or conda.
#
# **N.B.** you may have to restart the kernel after installing these packages for your first run.

# %%
#!/bin/env python

# install packages
# !pip3 install --user pandas
# !pip3 install --user numpy
# !pip3 install --user matplotlib
# !pip3 install --user plotly
# !pip3 install --user jupyter-dash
# Out:
# Requirement already satisfied: pandas in /opt/conda/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.7/site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.17.3 in /opt/conda/lib/python3.7/site-packages (from pandas) (1.19.5)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (1.19.5)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.7/site-packages (3.5.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib) (1.4.0)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.7/site-packages (from matplotlib) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.7/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.7/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.7/site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.7/site-packages (from matplotlib) (4.30.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib) (3.0.7)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.7/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib) (4.1.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: plotly in /home/jupyter/.local/lib/python3.7/site-packages (5.6.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from plotly) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.7/site-packages (from plotly) (8.0.1)
# Requirement already satisfied: jupyter-dash in /home/jupyter/.local/lib/python3.7/site-packages (0.4.1)
# Requirement already satisfied: dash in /home/jupyter/.local/lib/python3.7/site-packages (from jupyter-dash) (2.3.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from jupyter-dash) (2.27.1)
# Requirement already satisfied: ipykernel in /opt/conda/lib/python3.7/site-packages (from jupyter-dash) (6.9.2)
# Requirement already satisfied: retrying in /opt/conda/lib/python3.7/site-packages (from jupyter-dash) (1.3.3)
# Requirement already satisfied: ipython in /opt/conda/lib/python3.7/site-packages (from jupyter-dash) (7.32.0)
# Requirement already satisfied: flask in /home/jupyter/.local/lib/python3.7/site-packages (from jupyter-dash) (2.0.3)
# Requirement already satisfied: ansi2html in /home/jupyter/.local/lib/python3.7/site-packages (from jupyter-dash) (1.7.0)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.7/site-packages (from ansi2html->jupyter-dash) (4.11.3)
# Requirement already satisfied: dash-html-components==2.0.0 in /home/jupyter/.local/lib/python3.7/site-packages (from dash->jupyter-dash) (2.0.0)
# Requirement already satisfied: plotly>=5.0.0 in /home/jupyter/.local/lib/python3.7/site-packages (from dash->jupyter-dash) (5.6.0)
# Requirement already satisfied: flask-compress in /home/jupyter/.local/lib/python3.7/site-packages (from dash->jupyter-dash) (1.11)
# Requirement already satisfied: dash-table==5.0.0 in /home/jupyter/.local/lib/python3.7/site-packages (from dash->jupyter-dash) (5.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /home/jupyter/.local/lib/python3.7/site-packages (from dash->jupyter-dash) (2.0.0)
# Requirement already satisfied: click>=7.1.2 in /opt/conda/lib/python3.7/site-packages (from flask->jupyter-dash) (8.0.4)
# Requirement already satisfied: Werkzeug>=2.0 in /home/jupyter/.local/lib/python3.7/site-packages (from flask->jupyter-dash) (2.0.3)
# Requirement already satisfied: Jinja2>=3.0 in /opt/conda/lib/python3.7/site-packages (from flask->jupyter-dash) (3.0.3)
# Requirement already satisfied: itsdangerous>=2.0 in /home/jupyter/.local/lib/python3.7/site-packages (from flask->jupyter-dash) (2.1.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /opt/conda/lib/python3.7/site-packages (from ipykernel->jupyter-dash) (1.5.1)
# Requirement already satisfied: jupyter-client<8.0 in /opt/conda/lib/python3.7/site-packages (from ipykernel->jupyter-dash) (7.1.2)
# Requirement already satisfied: traitlets<6.0,>=5.1.0 in /opt/conda/lib/python3.7/site-packages (from ipykernel->jupyter-dash) (5.1.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in /opt/conda/lib/python3.7/site-packages (from ipykernel->jupyter-dash) (6.1)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.7/site-packages (from ipykernel->jupyter-dash) (5.9.0)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.7/site-packages (from ipykernel->jupyter-dash) (1.5.4)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /opt/conda/lib/python3.7/site-packages (from ipykernel->jupyter-dash) (0.1.3)
# Requirement already satisfied: setuptools>=18.5 in /opt/conda/lib/python3.7/site-packages (from ipython->jupyter-dash) (59.8.0)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.7/site-packages (from ipython->jupyter-dash) (0.18.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from ipython->jupyter-dash) (3.0.27)
# Requirement already satisfied: pygments in /opt/conda/lib/python3.7/site-packages (from ipython->jupyter-dash) (2.11.2)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.7/site-packages (from ipython->jupyter-dash) (0.7.5)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.7/site-packages (from ipython->jupyter-dash) (5.1.1)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.7/site-packages (from ipython->jupyter-dash) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.7/site-packages (from ipython->jupyter-dash) (4.8.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->jupyter-dash) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.7/site-packages (from requests->jupyter-dash) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->jupyter-dash) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->jupyter-dash) (1.26.8)
# Requirement already satisfied: six>=1.7.0 in /opt/conda/lib/python3.7/site-packages (from retrying->jupyter-dash) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/conda/lib/python3.7/site-packages (from jedi>=0.16->ipython->jupyter-dash) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.7/site-packages (from Jinja2>=3.0->flask->jupyter-dash) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.1 in /opt/conda/lib/python3.7/site-packages (from jupyter-client<8.0->ipykernel->jupyter-dash) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in /opt/conda/lib/python3.7/site-packages (from jupyter-client<8.0->ipykernel->jupyter-dash) (4.9.2)
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.7/site-packages (from jupyter-client<8.0->ipykernel->jupyter-dash) (0.4)
# Requirement already satisfied: pyzmq>=13 in /opt/conda/lib/python3.7/site-packages (from jupyter-client<8.0->ipykernel->jupyter-dash) (22.3.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.7/site-packages (from pexpect>4.3->ipython->jupyter-dash) (0.7.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.7/site-packages (from plotly>=5.0.0->dash->jupyter-dash) (8.0.1)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter-dash) (0.2.5)
# Requirement already satisfied: brotli in /home/jupyter/.local/lib/python3.7/site-packages (from flask-compress->dash->jupyter-dash) (1.0.9)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->ansi2html->jupyter-dash) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->ansi2html->jupyter-dash) (4.1.1)

# %% [markdown]
# Having installed the libraries, you can import them as follows.

# %%
# import libraries
# %matplotlib inline

#import plotly
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from plotly import express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from jupyter_dash import JupyterDash
from dash import dcc
from dash import html
from dash.dependencies import Input, Output, State

# Set display row/column to show all data
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# #!pip3 install --user plotly
# #import plotly
#
#
# ## Access Data From Endpoint
#
# #### Further Documentation
# https://docs.python-requests.org/en/master/

# %% [markdown]
# **N.B.** the url used in this example is from the demo project we have set up. Please replace it with your own url.

# %%
# define endpoint url
url = "https://dbgee-mar22-12.ew.r.appspot.com/api/text"
url = "

# %%
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import re

# %%
req = Request("https://www.db.com/media/news?languague_id=1")
html_page = urlopen(req)

# %%
html_page

# %%
import os
# !pip3 install beautifulsoup4

import requests
from bs4 import BeautifulSoup

URL = "https://www.db.com/media/news?tags=sustainability"
page = requests.get(URL)

# %%
soup = BeautifulSoup(page.content, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html data-cms-language-id="1" lang="en" prefix="og: http://ogp.me/ns#" xml:lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="//master.dwebcms.db.com/application/version/latest/files/DB-Share-Logo_1200x627.jpg" property="og:image"/>
# <meta content="//master.dwebcms.db.com/application/version/latest/files/DB-Share-Logo_1200x627.jpg" name="twitter:image"/>
# <meta content="https://www.db.com/media/news?language_id=1" property="og:url">
# <meta content="https://www.db.com/media/news?language_id=1" name="twitter:url">
# <title>Deutsche Bank news</title>
# <meta content="Deutsche Bank news" property="og:title"/>
# <meta content="Deutsche Bank news" name="twitter:title"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="Latest Deutsche Bank news. Use the search engine and filters to find archived items." name="description" property="og:description"/><meta content="Latest Deutsche Bank news. Use the search engine and filters to find archived items." name="twitter:description"/> <meta content="News" name="keywords"/> <link href="//master.dwebcms.db.com/application/themes/default/favicon/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="//master.dwebcms.db.com/application/themes/default/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="//master.dwebcms.db.com/application/themes/default/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="//master.dwebcms.db.com/application/themes/default/favicon/manifest.json" rel="manifest"/>
# <link color="#5bbad5" href="//master.dwebcms.db.com/application/themes/default/favicon/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="#ffffff" name="theme-color"/>
# <link href="//master.dwebcms.db.com/application/version/latest/css/mainStyles.css?20211031" rel="stylesheet" type="text/css">
# <script async="" data-settings-id="ploAW1D5w" id="usercentrics-cmp" src="https://app.usercentrics.eu/browser-ui/latest/loader.js"></script>
# <script src="https://privacy-proxy.usercentrics.eu/latest/uc-block.bundle.js" type="application/javascript"></script>
# <link href="/application/project/css/ghpStyles.css?1" rel="stylesheet"/>
# <link href="/application/project/css/dbcomStyles.css?2" rel="stylesheet"/>
# </link></meta></meta></head>
# <body class="anonymouslayout1607354318333 theme-default id-a386d9ad-4f93-4a24-8849-a1efc4f3a6ff" data-footer-consent-label="Cookies" data-sharing=" twitter linkedin facebook xing contact" data-sharing-enabled="true" data-text-link-social-title-contact="Share this page by email" data-text-link-social-title-facebook="Share this page on facebook" data-text-link-social-title-linkedin="Share this page on linkedin" data-text-link-social-title-twitter="Share this page on Twitter" data-text-link-social-title-xing="Share this page on xing" data-text-new-window-hint="opens in new window">
# <!--stopindex-->
# <script type="text/javascript">
#       window.config = window.config || {};
#       window.config.webSSO = {};
#       window.config.webSSO.url = '/websso-object';
#       window.config.webSSO.object = null;
#       window.config.webSSO.config = {
#         jsonpOptions: {
#           timeout: 10000,
#           jsonpCallbackFunction: 'webSSOobject',
#         },
#       };
#     </script>
# <header class="cms-row" data-wt-area="header">
# <div class="main-header cms-content-wrapper">
# <button class="button navigation-mobile-burger-menu">
# <span class="burger-open">
# <span class="hidden-title">open navigation</span>
# <svg>
# <use xlink:href="#svgsymbol-burger-menu" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <span class="burger-close">
# <span class="hidden-title">close Navigation</span>
# <svg>
# <use xlink:href="#svgsymbol-burger-close" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </button>
# <a class="identifier" href="/" id="identifier" target="_self" title="Home">
# <img alt="Deutsche Bank" src="/application/project/images/logos/identifier_RETINA.png"/> </a>
# <button class="button type-primary skip main-navigation" data-module="Skip" name="Skip to main content" title=" Skip to main content">
#        Skip to main content    </button>
# <nav class="navigation-cross">
# <ul>
# <li>
# <a href="https://www.db.com/media" target="_self" title="Media">
#                                     Media
#                               </a>
# </li>
# <li>
# <a href="https://www.db.com/careers" target="_self" title="Careers">
#                                     Careers
#                               </a>
# </li>
# <li>
# <a href="https://www.db.com/ir" target="_self" title="Investor Relations">
#                                     Investor Relations
#                               </a>
# </li>
# <li>
# <a href="https://www.dbresearch.com/" target="_self" title="Research">
#                                     Research
#                               </a>
# </li>
# <li>
# <a href="https://www.db.com/positiveimpact" target="_self" title="#PositiveImpact">
#                                     #PositiveImpact
#                               </a>
# </li>
# <li>
# <a href="https://www.db.com/responsibility" target="_self" title="Responsibility">
#                                     Responsibility
#                               </a>
# </li>
# <li>
# <a href="https://www.db.com/contact" target="_self" title="Contact">
#                                     Contact
#                               </a>
# </li>
# </ul>
# </nav>
# <a class="logo" href="https://www.db.com/" target="_self" title="Deutsche Bank Logo">
# <span class="hidden-title">Home</span>
# <svg focusable="false">
# <use xlink:href="#svgsymbol-logo" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </a>
# <button class="button type-primary skip main-navigation" data-module="Skip" name="Skip main navigation" title="Skip main navigation">
#       Skip main navigation    </button>
# </div>
# <div class="navigation-mobile" data-text-overview="Overview"></div>
# </header>
# <nav aria-label="press escape to close the menu" class="navigation-customer" data-text-overview="Overview" data-wt-area="navigation">
# <div class="cms-content-wrapper nav-wrapper">
# <ul class="nav-root">
# <li class="active">
# <a href="/index" title="Deutsche Bank">Deutsche Bank</a>
# </li>
# <li>
# <a href="https://corporates.db.com" target="_self" title="Corporates/Institutions">
#                                                                     Corporates/Institutions
#                                                              </a>
# </li>
# <li>
# <a href="https://www.db.com/start" target="_self" title="Private Clients">
#                                                                     Private Clients
#                                                              </a>
# </li>
# <li>
# <a href="https://www.db.com/logins" target="_self" title="Client logins">
#                                                                     Client logins
#                                                              </a>
# </li>
# <li>
# <a href="https://www.db.com/who-we-are/global-network/index" target="_self" title="Locations">
#                                                                     Locations
#                                                              </a>
# </li>
# </ul>
# </div>
# </nav>
# <nav class="navigation-main" data-module="MainNavigation" data-text-overview="Overview" data-wt-area="navigation">
# <div class="cms-content-wrapper nav-wrapper">
# <ul class="nav-root">
# <li>
# <a class="home-link" href="/index" title="Home">
# <span class="hidden-title">Home</span>
# <svg class="icon" focusable="false">
# <use xlink:href="#svgsymbol-home" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </a>
# </li>
# <li>
# <a href="/what-we-do" target="_self" title="What we do">
#                                                             What we do
#                                                     </a>
# <div class="entry-list-wrapper">
# <ul>
# <li>
# <a href="/what-we-do/products-and-services" target="_self" title="Products and services">
#                                                                                                     Products and services
#                                                                                               </a>
# <div class="entry-list-wrapper">
# <ul>
# <li>
# <a href="/what-we-do/products-and-services/corporate-bank" target="_self" title="Corporate Bank">
#                                                                                                                                             Corporate Bank
#                                                                                                                                       </a>
# </li>
# <li>
# <a href="/what-we-do/products-and-services/dws" target="_self" title="DWS">
#                                                                                                                                             DWS
#                                                                                                                                       </a>
# </li>
# <li>
# <a href="/what-we-do/products-and-services/investment-bank" target="_self" title="Investment Bank">
#                                                                                                                                             Investment Bank
#                                                                                                                                       </a>
# </li>
# <li>
# <a href="/what-we-do/products-and-services/private-bank" target="_self" title="Private Bank">
#                                                                                                                                             Private Bank
#                                                                                                                                       </a>
# </li>
# <li>
# <a href="/what-we-do/products-and-services/reports" target="_self" title="Deutsche Bank Reports">
#                                                                                                                                             Deutsche Bank Reports
#                                                                                                                                       </a>
# </li>
# <li>
# <a href="/what-we-do/products-and-services/client-logins" target="_self" title="Client logins">
#                                                                                                                                             Client logins
#                                                                                                                                       </a>
# </li>
# <li>
# <a href="https://www.db.com/who-we-are/global-network/index" target="_self" title="Locations worldwide">
#                                                                                                                                             Locations worldwide
#                                                                                                                                       </a>
# </li>
# <li>
# <a href="/what-we-do/products-and-services/mobile-services" target="_self" title="Mobile services">
#                                                                                                                                             Mobile services
#                                                                                                                                       </a>
# </li>
# <li>
# <a href="https://www.db.com/awards" target="_self" title="Awards">
#                                                                                                                                             Awards
#                                                                                                                                       </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/what-we-do/responsibility" target="_self" title="Responsibility">
#                                                                                                     Responsibility
#                                                                                               </a>
# <div class="entry-list-wrapper">
# <ul>
# <li>
# <a href="/what-we-do/responsibility/sustainability" target="_self" title="Sustainability">
#                                                                                                                                             Sustainability
#                                                                                                                                       </a>
# </li>
# <li>
# <a href="/what-we-do/responsibility/society" target="_self" title="Society">
#                                                                                                                                             Society
#                                                                                                                                       </a>
# </li>
# <li>
# <a href="/what-we-do/responsibility/art-culture-sports" target="_self" title="Art, Culture &amp; Sports">
#                                                                                                                                             Art, Culture &amp; Sports
#                                                                                                                                       </a>
# </li>
# <li>
# <a href="/what-we-do/responsibility/reports" target="_self" title="Reports">
#                                                                                                                                             Reports
#                                                                                                                                       </a>
# </li>
# <li>
# <a href="http://www.db.com/what-we-do/responsibility/sustainability/sustainability-deep-dive" target="_self" title="Sustainability Deep Dive">
#                                                                                                                                             Sustainability Deep Dive
#                                                                                                                                       </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/what-we-do/focus-topics" target="_self" title="Focus topics">
#                                                                                                     Focus topics
#                                                                                               </a>
# <div class="entry-list-wrapper">
# <ul>
# <li>
# <a href="/what-we-do/focus-topics/cloud" target="_self" title="Cloud">
#                                                                                                                                             Cloud
#                                                                                                                                       </a>
# </li>
# <li>
# <a href="/what-we-do/focus-topics/corporate-venture-capital" target="_self" title="Corporate Venture Capital">
#                                                                                                                                             Corporate Venture Capital
#                                                                                                                                       </a>
# </li>
# <li>
# <a href="/what-we-do/focus-topics/deutsche-bank-at-cop26" target="_self" title="Deutsche Bank at COP26">
#                                                                                                                                             Deutsche Bank at COP26
#                                                                                                                                       </a>
# </li>
# <li>
# <a href="/what-we-do/focus-topics/innovation-network" target="_self" title="Innovation Network">
#                                                                                                                                             Innovation Network
#                                                                                                                                       </a>
# </li>
# </ul>
# </div>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/who-we-are" target="_self" title="Who we are">
#                                                             Who we are
#                                                     </a>
# <div class="entry-list-wrapper">
# <ul>
# <li>
# <a href="/who-we-are/strategy" target="_self" title="Strategy">
#                                                                                                     Strategy
#                                                                                               </a>
# </li>
# <li>
# <a href="/who-we-are/our-culture" target="_self" title="Our culture">
#                                                                                                     Our culture
#                                                                                               </a>
# <div class="entry-list-wrapper">
# <ul>
# <li>
# <a href="/who-we-are/our-culture/diversity-management" target="_self" title="Diversity &amp; Inclusion">
#                                                                                                                                             Diversity &amp; Inclusion
#                                                                                                                                       </a>
# </li>
# <li>
# <a href="https://www.db.com/media/social-media/netiquette" target="_self" title="Netiquette">
#                                                                                                                                             Netiquette
#                                                                                                                                       </a>
# </li>
# <li>
# <a href="/who-we-are/our-culture/hr-report" target="_self" title="HR Report">
#                                                                                                                                             HR Report
#                                                                                                                                       </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/who-we-are/global-network" target="_self" title="Global network">
#                                                                                                     Global network
#                                                                                               </a>
# <div class="entry-list-wrapper">
# <ul>
# <li>
# <a href="/who-we-are/global-network/addresses-and-contact" target="_self" title="Addresses and contact">
#                                                                                                                                             Addresses and contact
#                                                                                                                                       </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/who-we-are/boards-and-committees" target="_self" title="Boards and committees">
#                                                                                                     Boards and committees
#                                                                                               </a>
# <div class="entry-list-wrapper">
# <ul>
# <li>
# <a href="/who-we-are/boards-and-committees/management-board" target="_self" title="Management Board">
#                                                                                                                                             Management Board
#                                                                                                                                       </a>
# </li>
# <li>
# <a href="https://investor-relations.db.com/corporate-governance/organizational-structure/supervisory-board?language_id=1" target="_self" title="Supervisory Board">
#                                                                                                                                             Supervisory Board
#                                                                                                                                       </a>
# </li>
# <li>
# <a href="https://investor-relations.db.com/corporate-governance/organizational-structure/committees-of-the-supervisory-board?language_id=1" target="_self" title="Committees of the Supervisory Board">
#                                                                                                                                             Committees of the Supervisory Board
#                                                                                                                                       </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/who-we-are/history" target="_self" title="History">
#                                                                                                     History
#                                                                                               </a>
# <div class="entry-list-wrapper">
# <ul>
# <li>
# <a href="/who-we-are/history/historical-institute" target="_self" title="Historical Institute">
#                                                                                                                                             Historical Institute
#                                                                                                                                       </a>
# </li>
# <li>
# <a href="/who-we-are/history/history-of-deutsche-bank" target="_self" title="History of Deutsche Bank">
#                                                                                                                                             History of Deutsche Bank
#                                                                                                                                       </a>
# </li>
# <li>
# <a href="/who-we-are/history/publications" target="_self" title="Historical publications">
#                                                                                                                                             Historical publications
#                                                                                                                                       </a>
# </li>
# <li>
# <a href="/who-we-are/history/faq" target="_self" title="Frequently asked questions">
#                                                                                                                                             Frequently asked questions
#                                                                                                                                       </a>
# </li>
# <li>
# <a href="http://www.banking-history.com/" target="_self" title="Historical Association of Deutsche Bank">
#                                                                                                                                             Historical Association of Deutsche Bank
#                                                                                                                                       </a>
# </li>
# </ul>
# </div>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a class="active" href="/media" target="_self" title="Media">
#                                                             Media
#                                                     </a>
# <div class="entry-list-wrapper">
# <ul>
# <li>
# <a class="active" href="/media/news" target="_self" title="Deutsche Bank news">
#                                                                                                     Deutsche Bank news
#                                                                                               </a>
# </li>
# <li>
# <a href="/media/events" target="_self" title="Events">
#                                                                                                     Events
#                                                                                               </a>
# </li>
# <li>
# <a href="/media/social-media" target="_self" title="Social Media">
#                                                                                                     Social Media
#                                                                                               </a>
# <div class="entry-list-wrapper">
# <ul>
# <li>
# <a href="https://www.db.com/media/deutsche-bank-on-social-media" target="_self" title="All social media channels">
#                                                                                                                                             All social media channels
#                                                                                                                                       </a>
# </li>
# <li>
# <a href="/media/social-media/netiquette" target="_self" title="Netiquette">
#                                                                                                                                             Netiquette
#                                                                                                                                       </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/media/videos" target="_self" title="Videos">
#                                                                                                     Videos
#                                                                                               </a>
# </li>
# <li>
# <a href="https://www.db.com/what-we-do/focus-topics/index" target="_self" title="Focus Topics">
#                                                                                                     Focus Topics
#                                                                                               </a>
# </li>
# <li>
# <a href="/media/images" target="_self" title="Images">
#                                                                                                     Images
#                                                                                               </a>
# </li>
# <li>
# <a href="/media/dbvoices" target="_self" title="#dbVoices">
#                                                                                                     #dbVoices
#                                                                                               </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/what-next" target="_self" title="What Next">
#                                                             What Next
#                                                     </a>
# <div class="entry-list-wrapper">
# <ul>
# <li>
# <a href="/what-next/responsible-growth" target="_self" title="Responsible Growth">
#                                                                                                     Responsible Growth
#                                                                                               </a>
# <div class="entry-list-wrapper">
# <ul>
# <li>
# <a href="https://www.db.com/water" title="The power of blue: will greater investment in water resources make for a more sustainable future?">Will greater investment in water resources make for a more sustainable future?</a>
# </li>
# <li>
# <a href="/what-next/responsible-growth/dossier-covid-sustainable-development" target="_self" title="Will Covid-19 be an opportunity or threat to sustainable development?">
#                                                                                                                                             Will Covid-19 be an opportunity or threat to sustainable development?
#                                                                                                                                       </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/what-next/digital-disruption" target="_self" title="Digital Disruption">
#                                                                                                     Digital Disruption
#                                                                                               </a>
# <div class="entry-list-wrapper">
# <ul>
# <li>
# <a href="/what-next/digital-disruption/better-than-humans" target="_self" title="AI in banking and business – what can it do and who stands to gain?">
#                                                                                                                                             AI in banking and business – what can it do and who stands to gain?
#                                                                                                                                       </a>
# </li>
# <li>
# <a href="/what-next/digital-disruption/dossier-future-financial-industry" target="_self" title="Banks or Fintechs – Who will be shaping the future of the financial industry?">
#                                                                                                                                             Banks or Fintechs – Who will be shaping the future of the financial industry?
#                                                                                                                                       </a>
# </li>
# <li>
# <a href="/what-next/digital-disruption/dossier-payments" target="_self" title="Cash, card, crypto: how the way you pay will affect your life">
#                                                                                                                                             Cash, card, crypto: how the way you pay will affect your life
#                                                                                                                                       </a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/what-next/entrepreneurial-success" target="_self" title="Entrepreneurial Success">
#                                                                                                     Entrepreneurial Success
#                                                                                               </a>
# <div class="entry-list-wrapper">
# <ul>
# <li>
# <a href="/what-next/entrepreneurial-success/Dossier-Bold-Moves" target="_self" title="What does it take to make bold moves in business?">
#                                                                                                                                             What does it take to make bold moves in business?
#                                                                                                                                       </a>
# </li>
# <li>
# <a href="/what-next/entrepreneurial-success/dossier-reset-for-growth" target="_self" title="How can companies and decision-makers reset for growth beyond corona virus?">
#                                                                                                                                             How can companies and decision-makers reset for growth beyond corona virus?
#                                                                                                                                       </a>
# </li>
# </ul>
# </div>
# </li>
# </ul>
# </div>
# </li>
# </ul>
# </div>
# </nav>
# <div data-module="ContentAnimation" id="content" role="main">
# <!--startindex-->
# <section class="cms-row row-index-1">
# <div class="cms-content-wrapper">
# <div class="cms-content">
# <div class="cms-column-100">
# <section class="cms-container cnt-breadcrumb" data-wt-area="stage-breadcrumb">
# <nav class="navigation-breadcrumb">
# <span class="breadcrumb-label">
#                             You are here:
#                     </span>
# <ul>
# <li>
# <a href="/" title="Home">
#                 Home
#               </a>
# </li>
# <li>
# <a href="/media" title="Media">
#                                                     Media
#                                               </a>
# </li>
# <li>News</li>
# </ul>
# </nav>
# </section>
# </div>
# </div>
# </div>
# </section>
# <section class="cms-row row-index-2">
# <div class="cms-content-wrapper">
# <div class="cms-content">
# <div class="cms-column-100">
# <section class="cms-container cnt-page-headline id-6b12b0ee-ed45-4b31-9926-4e29f901a4b8" data-wt-area="content">
# <section class="mod-page-headline id-96b182e9-e1c4-449f-910e-d063b22d3a7f">
# <h1>News</h1> </section>
# </section>
# </div>
# </div>
# </div>
# </section>
# <section class="cms-row row-index-3">
# <div class="cms-content-wrapper">
# <div class="cms-content">
# <div class="cms-column-100">
# <section class="cms-container cnt-generic id-8bdbc07e-a664-45fc-8976-062820f32b77" data-wt-area="content">
# <div class="mod-widget-news-stream" data-all-button-text="All" data-current-host="8e29bc28-e0f6-40f1-930a-6258631a0985" data-hosts="8e29bc28-e0f6-40f1-930a-6258631a0985" data-layout="block" data-limit="15" data-module="NewsStream" data-open-ext-link-new-tab="true" data-project-news-url="https://www.db.com/media/news" data-reset-text="Reset filter" data-search-aria-label="rwd.db.search.description" data-search-placeholder="Search" data-show-less-button-text="less" data-show-more-button-text="More" data-wt-area="news-stream-widget">
# <div class="news-stream-wrapper items-type-default">
# <div class="news-stream-entries-wrapper">
# <div aria-label="Loading..." class="mod-indicator" role="progressbar">
# </div>
# </div>
# <div class="news-stream-no-results hidden">
#           No results found for your selection, please make a new selection.        </div>
# <div class="news-stream-no-further-results hidden">
#           No further results found for your selection.        </div>
# <div class="news-stream-buttons">
# <button class="button type-primary wt-enabled">Load More</button>
# </div>
# </div>
# <script data-template-name="news-stream-item-layout" type="text/template">
#             ~entryTags~
#         <div class="news-stream-entry-content">
#       <div class="news-stream-entry-image type-small">
#                     <a href="~entryLink~" target="~entryLinkTarget~" title="~entryTitleHeadline~" class="wt-enabled">
#                 <figure class="mod-img-loader" data-img-src-large="~entryImage~" data-img-src-small="~entryImage~" data-img-alt="" data-img-option="src-small">
#                     <noscript>
#                         <img src="~entryImage~" alt=""/>
#                     </noscript>
#                     <div class="mod-indicator" role="progressbar" aria-label='Loading...'></div>
#                 </figure>
#             </a>
#             </div>
#       <div class="news-stream-entry-info">
#                     <div class="news-meta">
#                       ~entryType~
#                   <div class="news-meta-date">
#           ~entryDate~
#         </div>
#                 </div>
#                 <div class="news-stream-entry-description">
#              <a href="~entryLink~" target="~entryLinkTarget~" title="~entryTitleHeadline~" class="wt-enabled">
#               <h4>~entryHeadline~</h4>
#             </a>
#                             <a href="~entryLink~" target="~entryLinkTarget~" title="~entryTitleTeaserText~" class="wt-enabled">
#                     <p>~entryTeaser~</p>
#                 </a>
#                       </div>
#         </div>
# </script>
# </div>
# <script data-id="news-stream-filter-list" type="application/json">
#             {
#         "filters": [{
#                         "queryType": "types",
#                         "label": "Filter by news type",
#                         "options": [
#                         {
#                             "name": "Ad-hoc Release",
#                             "variable": "adHocRelease"
#                         },
#                         {
#                             "name": "Event",
#                             "variable": "event1"
#                         },
#                         {
#                             "name": "Media Release",
#                             "variable": "mediaRelease"
#                         },
#                         {
#                             "name": "News",
#                             "variable": "news"
#                         },
#                         {
#                             "name": "Research",
#                             "variable": "research"
#                         }]
#                     },
#                     {
#                         "queryType": "tags",
#                         "label": "Filter by topic",
#                         "options": [
#                         {"name": "Africa","variable": "africa"},
#                         {"name": "Americas","variable": "americas1"},
#                         {"name": "Asia-Pacific","variable": "asiapacific"},
#                         {"name": "Europe (ex Germany)","variable": "europeexGermany"},
#                         {"name": "Germany","variable": "germany"},
#                         {"name": "Middle East","variable": "middleEast"},
#                                                 {
#                                         "name": "Art",
#                                         "variable": "art"
#                                 },
#                                 {
#                                         "name": "Awards",
#                                         "variable": "awards"
#                                 },
#                                 {
#                                         "name": "Banking",
#                                         "variable": "banking"
#                                 },
#                                 {
#                                         "name": "Boards and Committees",
#                                         "variable": "boardsAndCommittees"
#                                 },
#                                 {
#                                         "name": "Bonds",
#                                         "variable": "bonds"
#                                 },
#                                 {
#                                         "name": "Brexit",
#                                         "variable": "brexit"
#                                 },
#                                 {
#                                         "name": "Capital markets",
#                                         "variable": "capitalMarkets"
#                                 },
#                                 {
#                                         "name": "Careers",
#                                         "variable": "careers"
#                                 },
#                                 {
#                                         "name": "Certificates",
#                                         "variable": "certificates"
#                                 },
#                                 {
#                                         "name": "Company",
#                                         "variable": "company1",
#                                         "color": "db-blue"
#                                 },
#                                 {
#                                         "name": "Corporate clients",
#                                         "variable": "corporateClients"
#                                 },
#                                 {
#                                         "name": "Corporate finance",
#                                         "variable": "corporateFinance"
#                                 },
#                                 {
#                                         "name": "Corporate Governance",
#                                         "variable": "corporateGovernance"
#                                 },
#                                 {
#                                         "name": "Corporate Responsibility",
#                                         "variable": "corporateResponsibility1"
#                                 },
#                                 {
#                                         "name": "Cryptocurrency",
#                                         "variable": "cryptocurrency"
#                                 },
#                                 {
#                                         "name": "Culture",
#                                         "variable": "culture"
#                                 },
#                                 {
#                                         "name": "Digital banking & services",
#                                         "variable": "digitalBankingServices"
#                                 },
#                                 {
#                                         "name": "Digitalisation",
#                                         "variable": "digitalisation",
#                                         "color": "grey"
#                                 },
#                                 {
#                                         "name": "Diversity",
#                                         "variable": "diversity"
#                                 },
#                                 {
#                                         "name": "Economy",
#                                         "variable": "economy"
#                                 },
#                                 {
#                                         "name": "Education – Born to Be",
#                                         "variable": "educationBornToBe"
#                                 },
#                                 {
#                                         "name": "Employee engagement",
#                                         "variable": "employeeEngagement"
#                                 },
#                                 {
#                                         "name": "Finance",
#                                         "variable": "finance"
#                                 },
#                                 {
#                                         "name": "Financial Results",
#                                         "variable": "financialResults"
#                                 },
#                                 {
#                                         "name": "Financing",
#                                         "variable": "financing"
#                                 },
#                                 {
#                                         "name": "Fintech",
#                                         "variable": "fintech"
#                                 },
#                                 {
#                                         "name": "Global reach",
#                                         "variable": "globalReach"
#                                 },
#                                 {
#                                         "name": "Green Bonds",
#                                         "variable": "greenBonds"
#                                 },
#                                 {
#                                         "name": "History",
#                                         "variable": "history"
#                                 },
#                                 {
#                                         "name": "Industry",
#                                         "variable": "industry"
#                                 },
#                                 {
#                                         "name": "Initial Public Offerings (IPOs)",
#                                         "variable": "initialPublicOfferingsIpos"
#                                 },
#                                 {
#                                         "name": "Innovation",
#                                         "variable": "innovation1",
#                                         "color": "orange"
#                                 },
#                                 {
#                                         "name": "Interview",
#                                         "variable": "interview"
#                                 },
#                                 {
#                                         "name": "Investment Fund",
#                                         "variable": "investmentFund"
#                                 },
#                                 {
#                                         "name": "Management & Leadership",
#                                         "variable": "managementLeadership"
#                                 },
#                                 {
#                                         "name": "Markets",
#                                         "variable": "markets"
#                                 },
#                                 {
#                                         "name": "Mergers & Acquisitions (M&A)",
#                                         "variable": "mergersAcquisitionsMA"
#                                 },
#                                 {
#                                         "name": "Microfinance",
#                                         "variable": "microfinance"
#                                 },
#                                 {
#                                         "name": "Personnel announcements",
#                                         "variable": "personnelAnnouncements"
#                                 },
#                                 {
#                                         "name": "Products & Services",
#                                         "variable": "productsServices"
#                                 },
#                                 {
#                                         "name": "Real Estate",
#                                         "variable": "realEstate"
#                                 },
#                                 {
#                                         "name": "Renewable Energy",
#                                         "variable": "renewableEnergy"
#                                 },
#                                 {
#                                         "name": "Renminbi",
#                                         "variable": "renminbi"
#                                 },
#                                 {
#                                         "name": "Retirement provision",
#                                         "variable": "retirementProvision"
#                                 },
#                                 {
#                                         "name": "Small businesses",
#                                         "variable": "smallBusinesses"
#                                 },
#                                 {
#                                         "name": "Social Responsibility",
#                                         "variable": "socialResponsibility"
#                                 },
#                                 {
#                                         "name": "Society",
#                                         "variable": "society"
#                                 },
#                                 {
#                                         "name": "Sports",
#                                         "variable": "sports"
#                                 },
#                                 {
#                                         "name": "Startups",
#                                         "variable": "startups"
#                                 },
#                                 {
#                                         "name": "Strategy",
#                                         "variable": "strategy"
#                                 },
#                                 {
#                                         "name": "Sustainability",
#                                         "variable": "sustainability",
#                                         "color": "dark-green"
#                                 },
#                                 {
#                                         "name": "Sustainable investment strategies / ESG",
#                                         "variable": "sustainableInvestmentStrategiesEsg"
#                                 },
#                                 {
#                                         "name": "Sustainable products",
#                                         "variable": "sustainableProducts"
#                                 },
#                                 {
#                                         "name": "Technology",
#                                         "variable": "technology"
#                                 },
#                                 {
#                                         "name": "Transaction Banking",
#                                         "variable": "transactionBanking"
# ...
# <symbol id="svgsymbol-logo" viewbox="0 0 32 32"><path d="M4.5 4.5v23h23v-23h-23zM0 0h32v32H0V0zm7 24.3L19.2 7.7H25L12.8 24.3H7z"></path></symbol>
# <symbol id="svgsymbol-play" viewbox="0 0 32 32"><path d="M27.197 16.78L5.863 29.06c-.666.383-1.53-.058-1.53-.781V3.722c0-.723.864-1.164 1.53-.78l21.334 12.277a.884.884 0 0 1 0 1.562z" fill-rule="evenodd"></path></symbol>
# <symbol id="svgsymbol-plus" viewbox="0 0 32 32"><path d="M28.727 14.727a1.273 1.273 0 1 1 0 2.546H3.273a1.273 1.273 0 0 1 0-2.546h25.454zm-14-11.454a1.273 1.273 0 0 1 2.546 0v25.454a1.273 1.273 0 1 1-2.546 0V3.273z"></path></symbol>
# <symbol id="svgsymbol-print" viewbox="0 0 32 32"><path d="M24.167 24.167v4.678c0 .638-.517 1.155-1.155 1.155H8.988a1.155 1.155 0 0 1-1.155-1.155v-4.678H3.155A1.155 1.155 0 0 1 2 23.012v-8.179c0-3.512 2.492-6.362 5.833-6.906V3.155C7.833 2.517 8.35 2 8.988 2h14.024c.638 0 1.155.517 1.155 1.155v4.772C27.508 8.471 30 11.321 30 14.833v8.179c0 .638-.517 1.155-1.155 1.155h-4.678zm0-2.334h3.5v-7c0-2.622-2.045-4.666-4.667-4.666H9c-2.622 0-4.667 2.044-4.667 4.666v7h3.5v-3.511c0-.638.517-1.155 1.155-1.155h14.024c.638 0 1.155.517 1.155 1.155v3.511zm-14-14h11.666v-3.5H10.167v3.5zm10.5 7V12.5h3.5v2.333h-3.5zm-10.5 4.667v8.167h11.666V19.5H10.167z"></path></symbol>
# <symbol id="svgsymbol-quotes" version="1" viewbox="0 0 57.000000 46.000000"><path d="M12.2 2.3C10.8 3.8 8.4 10.8 5 22.7c-2.7 10-5 18.9-5 19.8 0 2.3 4.5 4.1 7.3 2.8 1.8-.8 3.9-5.2 9.5-19.7C20.8 15.3 24 6.2 24 5.4 24 3 20.2 0 17.2 0c-1.7 0-3.7.9-5 2.3z"></path><path d="M45 1.8C43.4 3.1 41.6 8 37.9 21c-5.7 20.4-5.9 22.6-2.4 24.2 4.5 2 6.2-.4 13.6-19.2 3.7-9.6 6.8-18.7 6.8-20.2.1-5.1-6.6-7.5-10.9-4z"></path></symbol>
# <symbol id="svgsymbol-rate" viewbox="0 0 32 32"><path d="M30 12.6c-.1-.4-.4-.6-.8-.7l-8.5-1.3-3.8-8.1c-.3-.7-1.4-.7-1.7 0l-3.9 8.1-8.5 1.3c-.4.1-.6.3-.8.7-.1.4 0 .7.2 1l6.2 6.3-1.4 9c-.1.4.1.7.4 1 .3.2.7.2 1 .1l7.6-4.2 7.6 4.2c.1.1.3.1.4.1.2 0 .4-.1.5-.2.3-.2.4-.6.4-1L23.4 20l6.2-6.3c.4-.4.5-.7.4-1.1z"></path></symbol>
# <symbol id="svgsymbol-read_more" viewbox="0 0 32 32"><path d="M22.417 4C26.733 4 30 5.855 30 8.364v18.545c0 .655-.467 1.091-1.167 1.091s-1.166-.436-1.166-1.09c0-.874-2.1-2.183-5.25-2.183s-5.25 1.31-5.25 2.182V5.2c1.4-.764 3.15-1.2 5.25-1.2zm-7.584 1.2v21.71c0-.874-2.1-2.183-5.25-2.183s-5.25 1.31-5.25 2.182c0 .655-.466 1.091-1.166 1.091S2 27.564 2 26.91V8.363C2 5.854 5.267 4 9.583 4c2.1 0 3.85.436 5.25 1.2z" fill-rule="evenodd"></path></symbol>
# <symbol id="svgsymbol-rss" viewbox="0 0 32 32"><path d="M6 30a4 4 0 1 1 0-8 4 4 0 0 1 0 8zm24 0h-5.333C24.667 17.501 14.499 7.333 2 7.333V2c15.439 0 28 12.56 28 28zm-9.333 0h-5.334c0-7.352-5.981-13.333-13.333-13.333v-5.334c10.293 0 18.667 8.374 18.667 18.667z"></path></symbol>
# <symbol id="svgsymbol-search" viewbox="0 0 32 32"><path d="M22.398 19.103l7.424 7.423a.608.608 0 0 1 0 .86l-2.435 2.436a.607.607 0 0 1-.86 0l-7.425-7.424a11.034 11.034 0 0 1-6.21 1.772c-6.121-.107-10.997-5.156-10.89-11.278.107-6.121 5.156-10.997 11.277-10.89 6.122.107 10.997 5.156 10.89 11.277a11.034 11.034 0 0 1-1.77 5.824zm-9.312 2.46a8.477 8.477 0 1 0 0-16.954 8.477 8.477 0 0 0 0 16.954z"></path></symbol>
# <symbol id="svgsymbol-share" viewbox="0 0 32 32"><path d="M25.227 10.667c2.9 0 5.273-2.4 5.273-5.334C30.5 2.4 28.127 0 25.227 0c-2.9 0-5.272 2.4-5.272 5.333 0 .534.131.934.263 1.334l-9.623 5.6c-1.054-.934-2.372-1.6-3.822-1.6-2.9 0-5.273 2.4-5.273 5.333 0 2.933 2.373 5.333 5.273 5.333 1.45 0 2.768-.666 3.822-1.6l9.623 5.6c-.132.4-.263.934-.263 1.334 0 2.933 2.372 5.333 5.272 5.333 2.9 0 5.273-2.4 5.273-5.333 0-2.934-2.373-5.334-5.273-5.334-1.45 0-2.768.667-3.822 1.6l-9.623-5.6c.132-.4.263-.8.263-1.333 0-.533-.131-.933-.263-1.333l9.623-5.6c1.054.933 2.372 1.6 3.822 1.6z"></path></symbol>
# <symbol id="svgsymbol-sitemap" viewbox="0 0 32 32"><path d="M6 16.995v3.982H3.987V16c0-.645.4-.988 1.043-.988h9.973v-3.989h2.02v3.989h9.97c.645 0 1.004.343 1.004.988v4.977h-1.981v-3.982h-8.993v3.982h-2.02v-3.982H6zM16 10a4 4 0 1 1 0-8 4 4 0 0 1 0 8zM5 30a4 4 0 1 1 0-8 4 4 0 0 1 0 8zm11 0a4 4 0 1 1 0-8 4 4 0 0 1 0 8zm11 0a4 4 0 1 1 0-8 4 4 0 0 1 0 8z"></path></symbol>
# <symbol id="svgsymbol-socialmedia" viewbox="0 0 32 32"><path d="M17.75 27.27v-4.271c0-.483.392-.875.875-.875h8.75a.875.875 0 0 0 .875-.875V4.625a.875.875 0 0 0-.875-.875H4.625a.875.875 0 0 0-.875.875v16.624c0 .483.392.875.875.875h6.563c.202 0 .4.07.556.2l6.006 4.945zm1.75-3.396v5.25a.875.875 0 0 1-1.431.675l-7.195-5.925H4.625A2.625 2.625 0 0 1 2 21.249V4.625A2.625 2.625 0 0 1 4.625 2h22.75A2.625 2.625 0 0 1 30 4.625v16.624a2.625 2.625 0 0 1-2.625 2.625H19.5z"></path></symbol>
# <symbol id="svgsymbol-sound" viewbox="0 0 32 32"><path d="M17.142 6.544l-7.765 5.91H4.33v7.092h5.047l7.765 5.91V6.544zM8.6 10.09l8.975-6.83a1.181 1.181 0 0 1 1.896.94v23.6a1.181 1.181 0 0 1-1.896.94L8.6 21.91H3.181A1.181 1.181 0 0 1 2 20.73v-9.46c0-.652.529-1.181 1.181-1.181h5.42zm14.507 10.9a1.156 1.156 0 0 1-1.647 0 1.19 1.19 0 0 1 0-1.672c1.874-1.902 1.874-4.818 0-6.72a1.19 1.19 0 0 1 0-1.672 1.156 1.156 0 0 1 1.647 0c2.784 2.825 2.784 7.238 0 10.064zm3.494 3.073a1.156 1.156 0 0 1-1.647 0 1.19 1.19 0 0 1 0-1.672c3.622-3.675 3.622-9.664 0-13.34a1.19 1.19 0 0 1 0-1.671 1.156 1.156 0 0 1 1.647 0c4.532 4.598 4.532 12.084 0 16.683z"></path></symbol>
# <symbol id="svgsymbol-swipe" viewbox="0 0 24 24"><path d="M15 5h3V3l4 3.077L18 9V7h-3V5zM9 5H6V3L2 6.077 6 9V7h3V5zm9.33 5.679L13 10V5c0-.68-.31-1-1-1s-1 .32-1 1v9h-1v-2l-.928-.5c-.69 0-1.072.666-1.072 1.346v1.782c0 .838.54 1.652 1.072 2.306L11 21h7.011l1.837-8.224a1.85 1.85 0 0 0-1.518-2.097z"></path></symbol>
# <symbol id="svgsymbol-themeToggle" viewbox="0 0 32 32"><circle cx="16" cy="16" fill="none" r="15.486" stroke="#272727" stroke-linecap="round" stroke-linejoin="round" stroke-miterlimit="10" stroke-width="1.028"></circle><path d="M16 3A13 13 0 0 0 3 16a13 13 0 0 0 3.813 9.188L25.188 6.813A13 13 0 0 0 16 3z"></path></symbol>
# <symbol id="svgsymbol-twitter-dove-master" viewbox="0 0 32 32"><path d="M29.357 7.604a10.86 10.86 0 0 1-3.148.875 5.558 5.558 0 0 0 2.41-3.073 10.886 10.886 0 0 1-3.48 1.348 5.44 5.44 0 0 0-4-1.754c-3.028 0-5.482 2.487-5.482 5.554 0 .435.049.859.142 1.265-4.555-.231-8.593-2.442-11.296-5.802a5.584 5.584 0 0 0-.742 2.792 5.57 5.57 0 0 0 2.438 4.623 5.404 5.404 0 0 1-2.483-.695v.07c0 2.69 1.889 4.935 4.396 5.446a5.424 5.424 0 0 1-2.475.095c.698 2.206 2.722 3.812 5.12 3.857a10.905 10.905 0 0 1-8.114 2.3A15.365 15.365 0 0 0 11.044 27c10.082 0 15.594-8.463 15.594-15.802 0-.241-.005-.48-.016-.719 1.071-.783 2-1.76 2.735-2.875z"></path></symbol>
# <symbol id="svgsymbol-twitter" viewbox="0 0 32 32"><path d="M26.5 30h-21A3.501 3.501 0 0 1 2 26.5v-21C2 3.568 3.568 2 5.5 2h21C28.432 2 30 3.568 30 5.5v21c0 1.932-1.568 3.5-3.5 3.5zm-13.748-6.888c6.601 0 10.213-5.474 10.213-10.213 0-.154 0-.308-.007-.462a7.313 7.313 0 0 0 1.792-1.862 7.275 7.275 0 0 1-2.065.567 3.611 3.611 0 0 0 1.582-1.988 7.14 7.14 0 0 1-2.282.868 3.583 3.583 0 0 0-2.618-1.134 3.594 3.594 0 0 0-3.591 3.591c0 .28.035.553.091.819a10.193 10.193 0 0 1-7.399-3.752 3.6 3.6 0 0 0 1.113 4.795 3.63 3.63 0 0 1-1.624-.448v.049a3.597 3.597 0 0 0 2.877 3.521 3.5 3.5 0 0 1-.945.126c-.231 0-.455-.021-.672-.063a3.59 3.59 0 0 0 3.353 2.492 7.2 7.2 0 0 1-4.459 1.54c-.287 0-.574-.014-.854-.049a10.21 10.21 0 0 0 5.495 1.603z"></path></symbol>
# <symbol id="svgsymbol-upload" viewbox="0 0 32 32"><path d="M14.833 22h2.334v6h-2.334v-6zm9.313-9.424C27.224 11.74 30 14.156 30 17.2c0 2.65-2.09 4.8-4.667 4.8h-8.166v-4.8h4.666L16 11.2l-5.833 6h4.666V22h-7C4.613 22 2 19.313 2 16c0-3.073 2.254-5.578 5.15-5.93C8.333 6.54 11.583 4 15.417 4c4.693 0 8.513 3.804 8.729 8.576z" fill-rule="evenodd"></path></symbol>
# <symbol id="svgsymbol-views" viewbox="0 0 28 23"><path d="M27.46 8.364C25.59 5.848 20.533 0 14.002 0 7.388 0 2.378 5.853.532 8.364a2.751 2.751 0 0 0 .01 3.265C2.414 14.15 7.47 20 14.002 20c6.533 0 11.587-5.848 13.456-8.36a2.75 2.75 0 0 0 .001-3.276zM14 15a5 5 0 1 1 0-10 5 5 0 0 1 0 10z"></path></symbol>
# <symbol id="svgsymbol-xing" viewbox="0 0 32 32"><path class="xing-left" d="M8.832 9.152c-.178 0-.327.067-.402.197-.078.134-.066.306.017.481l1.99 3.676v.018L7.31 19.413a.514.514 0 0 0 0 .482.427.427 0 0 0 .385.214h2.943c.44 0 .652-.317.803-.607l3.177-5.996c-.012-.02-2.023-3.765-2.023-3.765-.147-.278-.368-.589-.82-.589H8.832z"></path><path class="xing-right" d="M21.235 5.5c-.451 0-.647.285-.81.577l-6.728 11.951 4.297 7.895c.15.269.381.577.844.577h3.02c.183 0 .325-.069.402-.194.08-.129.078-.3-.006-.468l-4.263-7.8v-.02L24.685 6.16c.085-.167.086-.338.007-.468-.077-.124-.22-.193-.402-.193h-3.055z"></path></symbol>
# <symbol id="svgsymbol-youtube" viewbox="0 0 32 32"><path d="M24.584 11.15c-.207-.86-.815-1.538-1.587-1.767-1.4-.418-7.012-.418-7.012-.418s-5.612 0-7.012.418c-.772.23-1.38.907-1.586 1.767-.375 1.56-.375 4.813-.375 4.813s0 3.253.375 4.813c.206.86.814 1.537 1.586 1.767 1.4.418 7.012.418 7.012.418s5.612 0 7.012-.418c.772-.23 1.38-.907 1.587-1.767.375-1.56.375-4.813.375-4.813s0-3.253-.375-4.813M14.19 18.962l4.663-2.999-4.662-3v6" fill-rule="evenodd"></path></symbol>
# </svg>
# <section class="modal-layer" data-module="ModalLayer">
# <div class="modal-layer-wrapper" id="modal-layer">
# <div class="modal-layer-close-wrapper">
# <button class="modal-layer-close">
# <span class="modal-layer-close-text">
#           close        </span>
# <svg focusable="false">
# <use xlink:href="#svgsymbol-close" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </button>
# </div>
# <div class="modal-layer-content"></div>
# <div class="modal-layer-loading-wrapper">
# <div aria-label="Loading..." class="mod-indicator" role="progressbar"></div>
# </div>
# </div>
# </section>
# <div class="mod-user-centrics-information">
# <script data-template-name="user-centrics-information" type="text/template">
#         <div class="user-centrics-content"></div>
#       <div class="button-wrapper">
#         <button class="button type-icon accept">
#           Edit cookie settings        </button>
#         <button class="button type-icon close">
#           Close        </button>
#       </div>
#       </script>
# </div>
# <div class="link-disclaimer-init" data-module="LinkDisclaimer"></div>
# <script data-template-name="link-disclaimer" type="text/template">
#       <div class="link-disclaimer">
#                     <h1>Disclaimer</h1>
#                             <div class="user-information-content">When you access this link, you are leaving the Deutsche Bank website and reach the page of another provider. Deutsche Bank does not endorse or accept any responsibility for information provided on any such sites. Any opinions or recommendations expressed on such other websites are solely those of the other providers. The existence of a link from this Deutsche Bank page to any other such websites does not constitute a recommendation or other approval by Deutsche Bank of such websites or any provider thereof.
# With the following buttons, you accept the above-mentioned information or remain on Deutsche Bank website.</div>
#                 <div class="button-wrapper">
#           <button class="button type-icon accept">Accept</button>
#           <button class="button type-icon close">Remain</button>
#         </div>
#       </div>
#     </script>
# <script src="//master.dwebcms.db.com/application/version/latest/js/mainJs.js?20211031" type="text/javascript"></script>
# <div aria-label="Toolbox" class="mod-toolbox" data-share-body="This content could be of interest to you:" data-share-subject="Recommendation of content" data-wt-area="toolbox" role="navigation">
# <ul>
# <li class="itm-toolbox">
# <a href="/media/news?language_id=3" target="_self" title="Language">
# <span class="icon">
#                                 DE
#                             </span>
# <span class="label">
#                                 Deutsch
#                             </span>
# </a>
# </li>
# <li class="itm-toolbox">
# <a href="/sitemap" target="_self" title="Sitemap">
# <span class="hidden-title">Sitemap</span>
# <svg class="icon" focusable="false">
# <use xlink:href="#svgsymbol-link" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <span class="label">Sitemap</span>
# </a>
# </li>
# <li class="itm-toolbox">
# <a href="/contact" target="_self" title="Contact">
# <span class="hidden-title">Contact</span>
# <svg class="icon" focusable="false">
# <use xlink:href="#svgsymbol-contact" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <span class="label">
#                                 Kontakt
#                             </span>
# </a>
# </li>
# <li class="itm-toolbox" data-module="ToolboxShare">
# <a href="#" target="_blank" title="Share">
# <span class="hidden-title">Share</span>
# <svg class="icon" focusable="false">
# <use xlink:href="#svgsymbol-share" xmlns:xlink="http://www.w3.org/1999/xlink">
# </use></svg>
# </a>
# </li>
# </ul>
# </div>
# <script src="/application/project/js/ghpJs.js"></script>
# <script src="/application/project/js/dbcomJs.js"></script>
# <script type="text/javascript">
#    window.config = window.config || {};
#    window.config.master = {
#      localization: {
#        dateFormat: 'DD MMMM YYYY',
#      },
#      config: {
#          cookieLayerIdentifier: 'bf96ab86-b171-48ee-a238-2a17e90ebff5'},
#    };
# </script>
# <svg class="svg-symbols" data-group-name="ghp">
# <symbol id="svgsymbol-apps" viewbox="0 0 32 32"><path d="M2 9h7V2H2v7zm10.5 21h7v-7h-7v7zM2 30h7v-7H2v7zm0-10.5h7v-7H2v7zm10.5 0h7v-7h-7v7zM23 2v7h7V2h-7zM12.5 9h7V2h-7v7zM23 19.5h7v-7h-7v7zM23 30h7v-7h-7v7z"></path></symbol>
# <symbol id="svgsymbol-facebook-scmlist" viewbox="0 0 32 32"><path d="M30 16.583C30 9.081 23.732 3 16 3S2 9.081 2 16.583C2 23.362 7.12 28.981 13.812 30v-9.491h-3.555v-3.926h3.555V13.59c0-3.404 2.09-5.284 5.288-5.284 1.532 0 3.134.265 3.134.265v3.343h-1.765c-1.739 0-2.281 1.047-2.281 2.121v2.548h3.883l-.621 3.926h-3.262V30C24.88 28.981 30 23.362 30 16.583z"></path></symbol>
# <symbol id="svgsymbol-flickr-scmlist" viewbox="0 0 32 32"><path d="M23.654 9.764c3.505 0 6.346 2.963 6.346 6.618S27.159 23 23.654 23s-6.346-2.963-6.346-6.618 2.841-6.618 6.346-6.618zm-15.486-.16c3.407 0 6.168 2.999 6.168 6.698S11.575 23 8.168 23 2 20.001 2 16.302s2.762-6.698 6.168-6.698z"></path></symbol>
# <symbol id="svgsymbol-linkedin-scmlist" viewbox="0 0 32 32"><path d="M26.111 2H5.889A3.889 3.889 0 0 0 2 5.889v20.222A3.889 3.889 0 0 0 5.889 30h20.222A3.889 3.889 0 0 0 30 26.111V5.889A3.889 3.889 0 0 0 26.111 2zM10.556 25.333H6.667V12.111h3.889v13.222zM8.599 10.556h-.021c-1.16 0-1.911-.865-1.911-1.945 0-1.104.774-1.944 1.955-1.944 1.183 0 1.912.84 1.934 1.944 0 1.079-.751 1.945-1.957 1.945zm12.845 14.777v-7.077c0-1.71-.953-2.876-2.483-2.876-1.167 0-1.799.787-2.105 1.548-.112.272-.079 1.025-.079 1.405v7h-3.889V12.111h3.889v2.035c.561-.868 1.439-2.035 3.685-2.035 2.783 0 4.87 1.75 4.87 5.658l.001 7.565h-3.889z"></path></symbol>
# <symbol id="svgsymbol-podcast" viewbox="0 0 32 32"><path d="M7.899 17.947l-.618-.639c-2.387-2.469-2.387-6.472 0-8.941l.618-.639 1.234 1.279-.617.639c-1.704 1.764-1.704 4.622 0 6.386l.617.638-1.234 1.277zM5.43 20.503l-.617-.639c-3.75-3.88-3.75-10.171 0-14.051l.617-.638 1.234 1.277-.617.639c-3.068 3.175-3.068 8.322 0 11.496l.617.639-1.234 1.277zm18.606-2.551l-1.234-1.277.617-.639c1.705-1.764 1.705-4.623 0-6.387l-.617-.639 1.234-1.277.617.639c2.387 2.469 2.387 6.472 0 8.941l-.617.639zm2.469 2.554l-1.234-1.277.617-.639c3.068-3.174 3.068-8.321 0-11.495l-.617-.639 1.234-1.277.617.639c3.749 3.88 3.749 10.17 0 14.05l-.617.638zM14 26h4v4h-4v-4zm7.205-9.548v-2.71h-2.619v-1.806h2.619v-2.71h-2.619V7.419h2.619V5.613C21.205 3.618 19.642 2 17.713 2h-3.492c-1.929 0-3.492 1.618-3.492 3.613v1.806h2.619v1.806H10.73v2.71h2.619v1.806H10.73v2.71h2.619v1.806H10.73v1.806c0 1.995 1.563 3.613 3.492 3.613h3.492c1.929 0 3.492-1.618 3.492-3.613v-1.806h-2.619v-1.806h2.618z"></path></symbol>
# </svg> </body>
# </html>

# %%
results = soup.find(id="news-stream-entry-description")
results = soup.find(a="")

# %%
print(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3323/2332316971.py in <module>
# ----> 1 print(results)
#
# NameError: name 'results' is not defined

# %%
URL
# Out:
# 'https://www.db.com/media/news?tags=sustainability'

# %%
results

# %%
soup = BeautifulSoup(html_page, "lxml")
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# /tmp/ipykernel_2183/4192096077.py in <module>
# ----> 1 soup = BeautifulSoup(html_page, "lxml")
#
# /opt/conda/lib/python3.7/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     246                     "Couldn't find a tree builder with the features you "
#     247                     "requested: %s. Do you need to install a parser library?"
# --> 248                     % ",".join(features))
#     249
#     250         # At this point either we have a TreeBuilder instance in
#
# FeatureNotFound: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?

# %%
links = []
for link in soup.findAll('a'):
    links.append(link.get('href'))

print(links)
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# /tmp/ipykernel_2183/1596088175.py in <module>
#       2 html_page = urlopen(req)
#       3
# ----> 4 soup = BeautifulSoup(html_page, "lxml")
#       5
#       6 links = []
#
# /opt/conda/lib/python3.7/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     246                     "Couldn't find a tree builder with the features you "
#     247                     "requested: %s. Do you need to install a parser library?"
# --> 248                     % ",".join(features))
#     249
#     250         # At this point either we have a TreeBuilder instance in
#
# FeatureNotFound: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?

# %%
soup
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2183/2212616996.py in <module>
# ----> 1 soup
#
# NameError: name 'soup' is not defined

# %%
https://www.db.com/media/news?languague_id=1"

url
# Out:
# 'https://www.db.com/media/news?languague_id=1'

# %%
# use requests library to send HTTP requests
# in this example, GET sentiment analysis data
#data = json.loads(requests.get(url).text)
requests.get(url).text

# examine data
# Out:
# '<!DOCTYPE html>\n<html prefix="og: http://ogp.me/ns#" lang="en" xml:lang="en" data-cms-language-id="1">\n  <head>\n    <meta charset="UTF-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n                      <meta property="og:image" content="//master.dwebcms.db.com/application/version/latest/files/DB-Share-Logo_1200x627.jpg">\n        <meta name="twitter:image" content="//master.dwebcms.db.com/application/version/latest/files/DB-Share-Logo_1200x627.jpg">\n              <meta property="og:url" content="https://www.db.com/media/news?language_id=1" />\n    <meta name="twitter:url" content="https://www.db.com/media/news?language_id=1" />\n              <title>Deutsche Bank news</title>\n      <meta property="og:title" content="Deutsche Bank news">\n      <meta name="twitter:title" content="Deutsche Bank news">\n        <meta name="twitter:card" content="summary">\n    <meta name="description" property="og:description" content="Latest Deutsche Bank news. Use the search engine and filters to find archived items."><meta name="twitter:description" content="Latest Deutsche Bank news. Use the search engine and filters to find archived items.">    <meta name="keywords" content="News">                <link rel="apple-touch-icon" sizes="180x180" href="//master.dwebcms.db.com/application/themes/default/favicon/apple-touch-icon.png">\n<link rel="icon" type="image/png" sizes="32x32" href="//master.dwebcms.db.com/application/themes/default/favicon/favicon-32x32.png">\n<link rel="icon" type="image/png" sizes="16x16" href="//master.dwebcms.db.com/application/themes/default/favicon/favicon-16x16.png">\n<link rel="manifest" href="//master.dwebcms.db.com/application/themes/default/favicon/manifest.json">\n<link rel="mask-icon" href="//master.dwebcms.db.com/application/themes/default/favicon/safari-pinned-tab.svg" color="#5bbad5">\n<meta name="theme-color" content="#ffffff">\n<link href="//master.dwebcms.db.com/application/version/latest/css/mainStyles.css?20211031" rel="stylesheet" type="text/css" />\n<script id="usercentrics-cmp" src="https://app.usercentrics.eu/browser-ui/latest/loader.js" data-settings-id="ploAW1D5w" async></script>\n<script type="application/javascript" src="https://privacy-proxy.usercentrics.eu/latest/uc-block.bundle.js"></script>\n        <link rel="stylesheet" href="/application/project/css/ghpStyles.css?1">\n<link rel="stylesheet" href="/application/project/css/dbcomStyles.css?2">\n\n  </head>\n  <body class="anonymouslayout1607354318333 theme-default id-a386d9ad-4f93-4a24-8849-a1efc4f3a6ff"\n        data-sharing=" twitter linkedin facebook xing contact"\n        data-sharing-enabled="true"\n        data-footer-consent-label="Cookies"\n                                        data-text-new-window-hint="opens in new window"        data-text-link-social-title-twitter="Share this page on Twitter"        data-text-link-social-title-linkedin="Share this page on linkedin"        data-text-link-social-title-facebook="Share this page on facebook"        data-text-link-social-title-xing="Share this page on xing"                                data-text-link-social-title-contact="Share this page by email">\n    <!--stopindex-->\n    <script type="text/javascript">\n      window.config = window.config || {};\n      window.config.webSSO = {};\n      window.config.webSSO.url = \'/websso-object\';\n      window.config.webSSO.object = null;\n      window.config.webSSO.config = {\n        jsonpOptions: {\n          timeout: 10000,\n          jsonpCallbackFunction: \'webSSOobject\',\n        },\n      };\n    </script>\n\n          <header class="cms-row" data-wt-area="header">\n  <div class="main-header cms-content-wrapper">\n    <button class="button navigation-mobile-burger-menu">\n      <span class="burger-open">\n        <span class="hidden-title">open navigation</span>\n        <svg >\n          <use xmlns:xlink="http://www.w3.org/199 ...

# %%
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /tmp/ipykernel_13647/3538722042.py in <module>
#       5 # use requests library to send HTTP requests
#       6 # in this example, GET sentiment analysis data
# ----> 7 data = json.loads(requests.get(url).text)
#       8
#       9 # examine data
#
# /opt/conda/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# /opt/conda/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /opt/conda/lib/python3.7/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
data
# Out:
# {'5631671361601536': {'text': 'it is sunny and bright outside and it will be colder overnight',
#   'timestamp': '2022-03-23 10:47:54.162574+00:00',
#   'sentiment': 'positive'},
#  '5632499082330112': {'text': 'it is sunny and birght',
#   'timestamp': '2022-03-23 10:46:37.100192+00:00',
#   'sentiment': 'neutral'},
#  '5634161670881280': {'text': 'sell horrible trees for money',
#   'timestamp': '2022-03-22 19:18:03.117197+00:00',
#   'sentiment': 'negative'},
#  '5635008819625984': {'text': 'Sell trees',
#   'timestamp': '2022-03-23 19:04:12.857337+00:00',
#   'sentiment': 'neutral'},
#  '5636645067948032': {'text': 'it is sunny and bright outside and it will be cold overnight',
#   'timestamp': '2022-03-23 10:47:23.058599+00:00',
#   'sentiment': 'positive'},
#  '5638358357245952': {'text': 'it is sunny and raining outside and it will be colder overnight',
#   'timestamp': '2022-03-23 10:48:02.497649+00:00',
#   'sentiment': 'negative'},
#  '5642368648740864': {'text': 'it is sunny and bright',
#   'timestamp': '2022-03-23 10:46:59.488532+00:00',
#   'sentiment': 'positive'},
#  '5643280054222848': {'text': "buy flowers for the weekend cos it's mother's day",
#   'timestamp': '2022-03-23 19:04:23.600202+00:00',
#   'sentiment': 'positive'},
#  '5644004762845184': {'text': 'seel beautiful trees for dreams',
#   'timestamp': '2022-03-22 19:18:45.523808+00:00',
#   'sentiment': 'positive'},
#  '5646488461901824': {'text': 'it is sunny and bright outside and it will be freezing overnight',
#   'timestamp': '2022-03-23 10:47:36.200417+00:00',
#   'sentiment': 'negative'},
#  '5704568633556992': {'text': 'Do trees like sunshine',
#   'timestamp': '2022-03-23 11:14:19.595612+00:00',
#   'sentiment': 'positive'}}

# %%
import urllib.request,sys,time
from bs4 import BeautifulSoup
import requests
import pandas as pd

pagesToGet= 1

upperframe=[]  
for page in range(1,pagesToGet+1):
    print('processing page :', page)
    url = 'https://www.db.com/media/news?languague_id=1?page='+str(page)
    print(url)
    
    #an exception might be thrown, so the code should be in a try-except block
    try:
        #use the browser to get the url. This is suspicious command that might blow up.
        page=requests.get(url)                             # this might throw an exception if something goes wrong.
    
    except Exception as e:                                   # this describes what to do if an exception is thrown
        error_type, error_obj, error_info = sys.exc_info()      # get the exception information
        print ('ERROR FOR LINK:',url)                          #print the link that cause the problem
        print (error_type, 'Line:', error_info.tb_lineno)     #print error info and line that threw the exception
        continue                                              #ignore this page. Abandon this and go back.
    time.sleep(2)   
    soup=BeautifulSoup(page.text,'html.parser')
    frame=[]
    links=soup.find_all('li',attrs={'class':'o-listicle__item'})
    print(len(links))
    filename="NEWS.csv"
    f=open(filename,"w", encoding = 'utf-8')
    headers="Statement,Link,Date, Source, Label\n"
    f.write(headers)
    
    for j in links:
        Statement = j.find("div",attrs={'class':'m-statement__quote'}).text.strip()
        Link = "https://www.db.com/media/news"
        Link += j.find("div",attrs={'class':'m-statement__quote'}).find('a')['href'].strip()
        Date = j.find('div',attrs={'class':'m-statement__body'}).find('footer').text[-14:-1].strip()
        Source = j.find('div', attrs={'class':'m-statement__meta'}).find('a').text.strip()
        Label = j.find('div', attrs ={'class':'m-statement__content'}).find('img',attrs={'class':'c-image__original'}).get('alt').strip()
        frame.append((Statement,Link,Date,Source,Label))
        f.write(Statement.replace(",","^")+","+Link+","+Date.replace(",","^")+","+Source.replace(",","^")+","+Label.replace(",","^")+"\n")
    upperframe.extend(frame)
f.close()
data=pd.DataFrame(upperframe, columns=['Statement','Link','Date','Source','Label'])
data.head()
# Out:
# processing page : 1
# https://www.db.com/media/news?languague_id=1?page=1
# 0
# Empty DataFrame
# Columns: [Statement, Link, Date, Source, Label]
# Index: []

# %% [markdown]
# ## Data Visualisation
#
# Plotly is a commonly-used data visualisation library. The following examples will show you how to create different graphs from the sample data.
#
# We can first read the sample data into a dataframe. The sample data is taken from the UK Met Office and shows the maximum and minimum temperature, the rainfall and the number of hours of sunlight for each month in 2018.

# %%
from google.cloud import language_v1

def sample_analyze_entities(text_content):
    """
    Analyzing Entities in a String

    Args:
      text_content The text content to analyze
    """

    client = language_v1.LanguageServiceClient()

    # text_content = 'California is a state.'

    # Available types: PLAIN_TEXT, HTML
    type_ = language_v1.Document.Type.PLAIN_TEXT

    # Optional. If not specified, the language is automatically detected.
    # For list of supported languages:
    # https://cloud.google.com/natural-language/docs/languages
    language = "en"
    document = {"content": text_content, "type_": type_, "language": language}

    # Available values: NONE, UTF8, UTF16, UTF32
    encoding_type = language_v1.EncodingType.UTF8

    response = client.analyze_entities(request = {'document': document, 'encoding_type': encoding_type})
    
    # TODO add in the filter file here
    filterEsgWords = open('articles/'+ file, "r")
    
    # Loop through entitites returned from the API
    for entity in response.entities:
        print(u"Representative name for the entity: {}".format(entity.name))

        # Get entity type, e.g. PERSON, LOCATION, ADDRESS, NUMBER, et al
        print(u"Entity type: {}".format(language_v1.Entity.Type(entity.type_).name))

        # Get the salience score associated with the entity in the [0, 1.0] range
        print(u"Salience score: {}".format(entity.salience))

        # Loop over the metadata associated with entity. For many known entities,
        # the metadata is a Wikipedia URL (wikipedia_url) and Knowledge Graph MID (mid).
        # Some entity types may have additional metadata, e.g. ADDRESS entities
        # may have metadata for the address street_name, postal_code, et al.
        for metadata_name, metadata_value in entity.metadata.items():
            print(u"{}: {}".format(metadata_name, metadata_value))

        # Loop over the mentions of this entity in the input document.
        # The API currently supports proper noun mentions.
        for mention in entity.mentions:
            print(u"Mention text: {}".format(mention.text.content))

            # Get the mention type, e.g. PROPER for proper noun
            print(
                u"Mention type: {}".format(language_v1.EntityMention.Type(mention.type_).name)
            )

    # Get the language of the text, which will be the same as
    # the language specified in the request or, if not specified,
    # the automatically-detected language.
    print(u"Language of the text: {}".format(response.language))

# %%
import os

# %%
# read sample csv data into dataframe
arcText = ''

for file in os.listdir('articles'):
    if not file.startswith('.'): 
        print(file)
        #got our articles
        article = open('articles/'+ file, "r")
        arcText = article.read()
        article.close()
        #print(arcText)
        sample_analyze_entities(arcText)
        #call POST on our endpoint
        #result = json.loads(requests.post(url).text)
# Out:
# ESG_Keywords.txt
# Representative name for the entity: Strategy
# Entity type: OTHER
# Salience score: 0.15074458718299866
# Mention text: Strategy
# Mention type: COMMON
# Representative name for the entity: Basic ## Environment Emissions Resource Use Innovation Social Human Rights Product Responsibility Workforce Community Governance Management Shareholders CSR
# Entity type: OTHER
# Salience score: 0.09136933088302612
# Mention text: Basic ##
# Environment
# Emissions
# Resource Use
# Innovation
# Social
# Human Rights
# Product Responsibility
# Workforce
# Community
# Governance
# Management
# Shareholders
# CSR
# Mention type: PROPER
# Representative name for the entity: Inclusion
# Entity type: OTHER
# Salience score: 0.07353918999433517
# Mention text: Inclusion
# Mention type: COMMON
# Representative name for the entity: Food Substance Misuse Workplace health
# Entity type: OTHER
# Salience score: 0.0543554425239563
# Mention text: Food Substance Misuse
# Workplace health
# Mention type: COMMON
# Representative name for the entity: Safety
# Entity type: OTHER
# Salience score: 0.04630867391824722
# Mention text: Safety
# Mention type: COMMON
# Representative name for the entity: Disinformation
# Entity type: OTHER
# Salience score: 0.040763940662145615
# Mention text: Disinformation
# Mention type: COMMON
# Representative name for the entity: Burnout Sugar
# Entity type: CONSUMER_GOOD
# Salience score: 0.040763940662145615
# Mention text: Burnout
# Sugar
# Mention type: COMMON
# Representative name for the entity: AI
# Entity type: OTHER
# Salience score: 0.04027317091822624
# Mention text: AI
# Mention type: COMMON
# Representative name for the entity: Recycling Ecotoxicity
# Entity type: OTHER
# Salience score: 0.03744826093316078
# Mention text: Recycling
# Ecotoxicity
# Mention type: COMMON
# Representative name for the entity: Racial Justice Disability LGBT+
# Entity type: ORGANIZATION
# Salience score: 0.03535667061805725
# Mention text: Racial Justice
# Disability
# LGBT+
# Mention type: PROPER
# Representative name for the entity: Ocean Acidification
# Entity type: LOCATION
# Salience score: 0.0321914479136467
# Mention text: Ocean Acidification
# Mention type: COMMON
# Representative name for the entity: Automation Future of Work Health Addiction Fake News Anti-microbial Resistance Mental Health Food
# Entity type: ORGANIZATION
# Salience score: 0.03019801340997219
# Mention text: Automation
# Future of Work
# Health
# Addiction
# Fake News
# Anti-microbial Resistance
# Mental Health
# Food
# Mention type: PROPER
# Representative name for the entity: Topsoil Loss Discrimination Conduct Board Remuneration Data Tax Homophobia
# Entity type: OTHER
# Salience score: 0.0283169187605381
# Mention text: Topsoil Loss
# Discrimination
# Conduct
# Board
# Remuneration
# Data
# Tax
# Homophobia
# Mention type: COMMON
# Representative name for the entity: Bullying
# Entity type: OTHER
# Salience score: 0.0283169187605381
# Mention text: Bullying
# Mention type: COMMON
# Representative name for the entity: Racism
# Entity type: OTHER
# Salience score: 0.0283169187605381
# Mention text: Racism
# Mention type: COMMON
# Representative name for the entity: Behavior
# Entity type: OTHER
# Salience score: 0.0283169187605381
# Mention text: Behavior
# Mention type: COMMON
# Representative name for the entity: Nutrition Hunger Living Wage Digital Inclusion Financial Inclusion Working Conditions Gender Equality Diversity Waste Climate Change Biodiversity Water Resource
# Entity type: ORGANIZATION
# Salience score: 0.025316309183835983
# Mention text: Nutrition Hunger
# Living Wage Digital Inclusion
# Financial Inclusion
# Working Conditions
# Gender Equality
# Diversity
# Waste
# Climate Change
# Biodiversity
# Water
# Resource
# Mention type: PROPER
# Representative name for the entity: Vulnerable Communities Worker Safety Refugees Inequality Human Trafficking Access In-Work Poverty Conflict Minerals Forced Labor Migration Child Labor Education Human Rights Freedom of Assembly Skills Alcohol Abuse Just Transition Healthcare Access to Justice Drug Pricing Gambling Labor Relations
# Entity type: OTHER
# Salience score: 0.023952359333634377
# Mention text: Vulnerable Communities Worker Safety
# Refugees
# Inequality
# Human Trafficking
# Access In-Work Poverty
# Conflict Minerals
# Forced Labor
# Migration Child Labor
# Education
# Human Rights
# Freedom of Assembly
# Skills
# Alcohol Abuse
# Just Transition
# Healthcare
# Access to Justice
# Drug Pricing
# Gambling
# Labor Relations
# Mention type: PROPER
# Representative name for the entity: Pay
# Entity type: OTHER
# Salience score: 0.023017607629299164
# Mention text: Pay
# Mention type: COMMON
# Representative name for the entity: Competency
# Entity type: OTHER
# Salience score: 0.022611750289797783
# Mention text: Competency
# Mention type: COMMON
# Representative name for the entity: Privacy
# Entity type: OTHER
# Salience score: 0.01988064870238304
# Mention text: Privacy
# Mention type: COMMON
# Representative name for the entity: Harassment Transphobia Rate Fixing Oversight Bribery Fraud Composition Criminal Misconduct Data Misuse Capacity
# Entity type: OTHER
# Salience score: 0.01988064870238304
# Mention text: Harassment
# Transphobia
# Rate Fixing
# Oversight
# Bribery
# Fraud
# Composition
# Criminal Misconduct
# Data Misuse
# Capacity
# Mention type: COMMON
# Representative name for the entity: CEO
# Entity type: PERSON
# Salience score: 0.01988064870238304
# Mention text: CEO
# Mention type: COMMON
# Representative name for the entity: Corporate Tax Data Stewardship Tax Avoidance Bonuses Dividends
# Entity type: OTHER
# Salience score: 0.01988064870238304
# Mention text: Corporate Tax
# Data Stewardship
# Tax Avoidance
# Bonuses Dividends
# Mention type: COMMON
# Representative name for the entity: Money Laundering Corruption Transparency Sexism Workplace Conduct Financial Crime
# Entity type: OTHER
# Salience score: 0.01911953091621399
# Mention text: Money Laundering
# Corruption
# Transparency
# Sexism
# Workplace Conduct
# Financial Crime
# Mention type: PROPER
# Representative name for the entity: Deforestation Sea
# Entity type: OTHER
# Salience score: 0.012487486936151981
# Mention text: Deforestation
# Sea
# Mention type: COMMON
# Representative name for the entity: Ocean Plastic Food Waste Circular Economy Rare Earths Pollution Extraction Desertification Water Scarcity Air Quality Soil Drinkable Water Soil Acidification Crop Yields Pesticides Regenerative Agriculture Fertilizers Clean Energy Bee Fertility Net Zero Climate Adaptation Floods Carbon Emissions Conservation Animal Welfare Mass Extinction Ecosystem Collapse
# Entity type: ORGANIZATION
# Salience score: 0.007392013445496559
# Mention text: Ocean Plastic
# Food Waste
# Circular Economy
# Rare Earths
# Pollution
# Extraction Desertification
# Water Scarcity Air Quality
# Soil
# Drinkable Water
# Soil Acidification
# Crop Yields
# Pesticides
# Regenerative Agriculture
# Fertilizers
# Clean Energy
# Bee Fertility
# Net Zero
# Climate Adaptation
# Floods
# Carbon Emissions
# Conservation
# Animal Welfare
# Mass Extinction
# Ecosystem Collapse
# Mention type: PROPER
# Representative name for the entity: Zero
# Entity type: NUMBER
# Salience score: 0.0
# value: 0
# Mention text: Zero
# Mention type: TYPE_UNKNOWN
# Language of the text: en
# article2.txt
# Representative name for the entity: Deutsche Bank
# Entity type: ORGANIZATION
# Salience score: 0.2161695808172226
# mid: /m/02lc8s
# wikipedia_url: https://en.wikipedia.org/wiki/Deutsche_Bank
# Mention text: Deutsche Bank
# Mention type: PROPER
# Mention text: Deutsche Bank
# Mention type: PROPER
# Mention text: Deutsche Bank
# Mention type: PROPER
# Mention text: Deutsche Bank
# Mention type: PROPER
# Mention text: Deutsche Bank
# Mention type: PROPER
# Mention text: Deutsche Bank
# Mention type: PROPER
# Mention text: Deutsche Bank
# Mention type: PROPER
# Mention text: Deutsche Bank
# Mention type: PROPER
# Mention text: Deutsche Bank
# Mention type: PROPER
# Mention text: Deutsche Bank
# Mention type: PROPER
# Mention text: Deutsche Bank
# Mention type: PROPER
# Mention text: Deutsche Bank
# Mention type: PROPER
# Mention text: Deutsche Bank
# Mention type: PROPER
# Mention text: Deutsche Bank
# Mention type: PROPER
# Mention text: Deutsche Bank
# Mention type: PROPER
# Mention text: Deutsche Bank
# Mention type: PROPER
# Mention text: DB
# Mention type: PROPER
# Representative name for the entity: ratio
# Entity type: OTHER
# Salience score: 0.03985849767923355
# Mention text: ratio
# Mention type: COMMON
# Mention text: ratio
# Mention type: COMMON
# Mention text: ratio
# Mention type: COMMON
# Mention text: ratio
# Mention type: COMMON
# Mention text: ratio
# Mention type: COMMON
# Mention text: ratio
# Mention type: COMMON
# Representative name for the entity: profit
# Entity type: OTHER
# Salience score: 0.02954608015716076
# Mention text: profit
# Mention type: COMMON
# Mention text: profit
# Mention type: COMMON
# Representative name for the entity: line
# Entity type: OTHER
# Salience score: 0.020578870549798012
# Mention text: line
# Mention type: COMMON
# Mention text: line
# Mention type: COMMON
# Mention text: line
# Mention type: COMMON
# Mention text: line
# Mention type: COMMON
# Representative name for the entity: return
# Entity type: EVENT
# Salience score: 0.01597690023481846
# Mention text: return
# Mention type: COMMON
# Mention text: return
# Mention type: COMMON
# Representative name for the entity: provision
# Entity type: OTHER
# Salience score: 0.014000861905515194
# Mention text: provision
# Mention type: COMMON
# Mention text: provision
# Mention type: COMMON
# Mention text: provision
# Mention type: COMMON
# Representative name for the entity: profit
# Entity type: OTHER
# Salience score: 0.012244142591953278
# Mention text: profit
# Mention type: COMMON
# Representative name for the entity: Capital Release Unit
# Entity type: ORGANIZATION
# Salience score: 0.010478468611836433
# Mention text: Capital Release Unit
# Mention type: PROPER
# Mention text: Capital Release Unit
# Mention type: PROPER
# Mention text: Capital Release Unit
# Mention type: PROPER
# Mention text: Capital Release Unit
# Mention type: PROPER
# Mention text: Capital Release Unit
# Mention type: PROPER
# Mention text: Capital Release Unit
# Mention type: PROPER
# Representative name for the entity: income
# Entity type: OTHER
# Salience score: 0.009988566860556602
# Mention text: income
# Mention type: COMMON
# Mention text: income
# Mention type: COMMON
# Mention text: income
# Mention type: COMMON
# Representative name for the entity: Bank
# Entity type: ORGANIZATION
# Salience score: 0.009184105321764946
# Mention text: Bank
# Mention type: COMMON
# Representative name for the entity: revenues
# Entity type: OTHER
# Salience score: 0.009122157469391823
# Mention text: revenues
# Mention type: COMMON
# Mention text: revenues
# Mention type: COMMON
# Representative name for the entity: Corporate Bank
# Entity type: ORGANIZATION
# Salience score: 0.008977704681456089
# mid: /m/0h7nbcy
# wikipedia_url: https://en.wikipedia.org/wiki/The_Co-operative_Bank_(New_Zealand)
# Mention text: Corporate Bank
# Mention type: COMMON
# Mention text: Corporate Bank
# Mention type: PROPER
# Representative name for the entity: Private Bank
# Entity type: ORGANIZATION
# Salience score: 0.008653179742395878
# mid: /m/025sjqj
# wikipedia_url: https://en.wikipedia.org/wiki/Private_banking
# Mention text: Private Bank
# Mention type: PROPER
# Mention text: Private Bank
# Mention type: PROPER
# Mention text: Private Bank
# Mention type: PROPER
# Mention text: Private Bank
# Mention type: PROPER
# Mention text: Private Bank
# Mention type: PROPER
# Mention text: Private Bank
# Mention type: PROPER
# Mention text: Private Bank
# Mention type: PROPER
# Mention text: Private Bank
# Mention type: PROPER
# Representative name for the entity: revenues
# Entity type: OTHER
# Salience score: 0.007978172041475773
# Mention text: revenues
# Mention type: COMMON
# Representative name for the entity: tax
# Entity type: OTHER
# Salience score: 0.007376559544354677
# Mention text: tax
# Mention type: COMMON
# Mention text: tax
# Mention type: COMMON
# Representative name for the entity: cost
# Entity type: OTHER
# Salience score: 0.007279066368937492
# Mention text: cost
# Mention type: COMMON
# Representative name for the entity: costs
# Entity type: OTHER
# Salience score: 0.007279066368937492
# Mention text: costs
# Mention type: COMMON
# Representative name for the entity: costs
# Entity type: OTHER
# Salience score: 0.007279066368937492
# Mention text: costs
# Mention type: COMMON
# Representative name for the entity: Core Bank
# Entity type: ORGANIZATION
# Salience score: 0.007264298852533102
# mid: /g/11b7cr9g2h
# Mention text: Core Bank
# Mention type: PROPER
# Mention text: Core Bank
# Mention type: PROPER
# Mention text: Core Bank
# Mention type: PROPER
# Mention text: Core Bank
# Mention type: PROPER
# Mention text: Core Bank
# Mention type: PROPER
# Mention text: Core Bank
# Mention type: PROPER
# Mention text: Core Bank
# Mention type: PROPER
# Representative name for the entity: ratio1
# Entity type: OTHER
# Salience score: 0.0068188817240297794
# Mention text: ratio¹
# Mention type: COMMON
# Representative name for the entity: ratio
# Entity type: OTHER
# Salience score: 0.0068188817240297794
# Mention text: ratio
# Mention type: COMMON
# Representative name for the entity: tax
# Entity type: OTHER
# Salience score: 0.006160194519907236
# Mention text: tax
# Mention type: COMMON
# Representative name for the entity: tax
# Entity type: OTHER
# Salience score: 0.006160194519907236
# Mention text: tax
# Mention type: COMMON
# Representative name for the entity: tax
# Entity type: OTHER
# Salience score: 0.006160194519907236
# Mention text: tax
# Mention type: COMMON
# Representative name for the entity: capital
# Entity type: OTHER
# Salience score: 0.006160194519907236
# Mention text: capital
# Mention type: COMMON
# Representative name for the entity: loss
# Entity type: OTHER
# Salience score: 0.006034636404365301
# Mention text: loss
# Mention type: COMMON
# Representative name for the entity: Asset Management
# Entity type: OTHER
# Salience score: 0.006034636404365301
# Mention text: Asset Management
# Mention type: COMMON
# Representative name for the entity: credit losses
# Entity type: OTHER
# Salience score: 0.006034636404365301
# Mention text: credit losses
# Mention type: COMMON
# Representative name for the entity: profit growth
# Entity type: OTHER
# Salience score: 0.00590323144569993
# Mention text: profit growth
# Mention type: COMMON
# Representative name for the entity: Business growth
# Entity type: OTHER
# Salience score: 0.00590323144569993
# Mention text: Business growth
# Mention type: COMMON
# Representative name for the entity: markets
# Entity type: OTHER
# Salience score: 0.005765257868915796
# Mention text: markets
# Mention type: COMMON
# Representative name for the entity: income
# Entity type: OTHER
# Salience score: 0.005765257868915796
# Mention text: income
# Mention type: COMMON
# Representative name for the entity: Provision
# Entity type: OTHER
# Salience score: 0.005765257868915796
# Mention text: Provision
# Mention type: COMMON
# Representative name for the entity: assets
# Entity type: OTHER
# Salience score: 0.005765257868915796
# Mention text: assets
# Mention type: COMMON
# Representative name for the entity: income
# Entity type: OTHER
# Salience score: 0.005765257868915796
# Mention text: income
# Mention type: COMMON
# Representative name for the entity: Transformation
# Entity type: OTHER
# Salience score: 0.005619843490421772
# Mention text: Transformation
# Mention type: COMMON
# Representative name for the entity: target
# Entity type: OTHER
# Salience score: 0.005619843490421772
# Mention text: target
# Mention type: COMMON
# Representative name for the entity: expenses
# Entity type: OTHER
# Salience score: 0.005465912166982889
# Mention text: expenses
# Mention type: COMMON
# Representative name for the entity: inflows
# Entity type: OTHER
# Salience score: 0.005465912166982889
# Mention text: inflows
# Mention type: COMMON
# Representative name for the entity: inflows
# Entity type: OTHER
# Salience score: 0.005465912166982889
# Mention text: inflows
# Mention type: COMMON
# Representative name for the entity: ESG
# Entity type: ORGANIZATION
# Salience score: 0.005306370556354523
# mid: /m/0by114h
# wikipedia_url: https://en.wikipedia.org/wiki/Environmental,_social_and_corporate_governance
# Mention text: ESG
# Mention type: PROPER
# Mention text: ESG
# Mention type: PROPER
# Mention text: ESG
# Mention type: PROPER
# Mention text: ESG
# Mention type: PROPER
# Mention text: ESG
# Mention type: PROPER
# Mention text: ESG
# Mention type: PROPER
# Representative name for the entity: profit
# Entity type: OTHER
# Salience score: 0.005197078455239534
# Mention text: profit
# Mention type: COMMON
# Mention text: profit
# Mention type: COMMON
# Representative name for the entity: effects
# Entity type: OTHER
# Salience score: 0.005126740783452988
# Mention text: effects
# Mention type: COMMON
# Representative name for the entity: risk
# Entity type: OTHER
# Salience score: 0.004731412976980209
# Mention text: risk
# Mention type: COMMON
# Representative name for the entity: investment products
# Entity type: CONSUMER_GOOD
# Salience score: 0.004731412976980209
# Mention text: investment products
# Mention type: COMMON
# Representative name for the entity: equity
# Entity type: OTHER
# Salience score: 0.004731412976980209
# Mention text: equity
# Mention type: COMMON
# Representative name for the entity: progress
# Entity type: OTHER
# Salience score: 0.004731412976980209
# Mention text: progress
# Mention type: COMMON
# Representative name for the entity: risk
# Entity type: OTHER
# Salience score: 0.004731412976980209
# Mention text: risk
# Mention type: COMMON
# Representative name for the entity: RWAs
# Entity type: OTHER
# Salience score: 0.004731412976980209
# Mention text: RWAs
# Mention type: COMMON
# Representative name for the entity: expenses
# Entity type: OTHER
# Salience score: 0.004699040204286575
# Mention text: expenses
# Mention type: COMMON
# Mention text: expenses
# Mention type: COMMON
# Representative name for the entity: Assets under Management
# Entity type: OTHER
# Salience score: 0.004675676580518484
# wikipedia_url: https://en.wikipedia.org/wiki/Assets_under_management
# mid: /g/120n_lnv
# Mention text: Assets under Management
# Mention type: COMMON
# Mention text: Assets under Management
# Mention type: PROPER
# Mention text: Assets under Management
# Mention type: PROPER
# Representative name for the entity: exposure
# Entity type: OTHER
# Salience score: 0.00458551337942481
# Mention text: exposure
# Mention type: COMMON
# Representative name for the entity: effects1
# Entity type: OTHER
# Salience score: 0.004396660253405571
# Mention text: effects1
# Mention type: COMMON
# Mention text: effects1
# Mention type: COMMON
# Representative name for the entity: Common Equity Tier
# Entity type: ORGANIZATION
# Salience score: 0.004249312914907932
# Mention text: Common Equity Tier
# Mention type: COMMON
# Representative name for the entity: Germany
# Entity type: LOCATION
# Salience score: 0.004194813314825296
# mid: /m/0345h
# wikipedia_url: https://en.wikipedia.org/wiki/Germany
# Mention text: Germany
# Mention type: PROPER
# Mention text: Germany
# Mention type: PROPER
# Mention text: Germany
# Mention type: PROPER
# Mention text: Germany
# Mention type: PROPER
# Representative name for the entity: loans
# Entity type: OTHER
# Salience score: 0.004080123733729124
# Mention text: loans
# Mention type: COMMON
# Mention text: loans
# Mention type: COMMON
# Mention text: loans
# Mention type: COMMON
# Mention text: loans
# Mention type: COMMON
# Representative name for the entity: BGH
# Entity type: ORGANIZATION
# Salience score: 0.003839354030787945
# Mention text: BGH
# Mention type: PROPER
# Mention text: BGH
# Mention type: PROPER
# Mention text: BGH
# Mention type: PROPER
# Mention text: BGH
# Mention type: PROPER
# Mention text: BGH
# Mention type: PROPER
# Mention text: BGH
# Mention type: PROPER
# Representative name for the entity: discipline
# Entity type: OTHER
# Salience score: 0.0036094198003411293
# Mention text: discipline
# Mention type: COMMON
# Representative name for the entity: balance sheet
# Entity type: OTHER
# Salience score: 0.0036094198003411293
# Mention text: balance sheet
# Mention type: COMMON
# Representative name for the entity: cost
# Entity type: OTHER
# Salience score: 0.003497386584058404
# Mention text: cost
# Mention type: COMMON
# Representative name for the entity: cost
# Entity type: OTHER
# Salience score: 0.003497386584058404
# Mention text: cost
# Mention type: COMMON
# Representative name for the entity: costs
# Entity type: OTHER
# Salience score: 0.003497386584058404
# Mention text: costs
# Mention type: COMMON
# Representative name for the entity: ruling
# Entity type: OTHER
# Salience score: 0.0033790559973567724
# Mention text: ruling
# Mention type: COMMON
# Mention text: ruling
# Mention type: COMMON
# Mention text: ruling
# Mention type: COMMON
# Mention text: ruling
# Mention type: COMMON
# Representative name for the entity: ratio
# Entity type: OTHER
# Salience score: 0.0032758000306785107
# Mention text: ratio
# Mention type: COMMON
# Representative name for the entity: RoTE
# Entity type: ORGANIZATION
# Salience score: 0.003233171533793211
# Mention text: RoTE
# Mention type: PROPER
# Representative name for the entity: net profit
# Entity type: OTHER
# Salience score: 0.0032274513505399227
# Mention text: net profit
# Mention type: COMMON
# Representative name for the entity: profit
# Entity type: OTHER
# Salience score: 0.0032274513505399227
# Mention text: profit
# Mention type: COMMON
# Representative name for the entity: profit
# Entity type: OTHER
# Salience score: 0.0032274513505399227
# Mention text: profit
# Mention type: COMMON
# Representative name for the entity: cuts
# Entity type: OTHER
# Salience score: 0.0031707154121249914
# Mention text: cuts
# Mention type: COMMON
# Representative name for the entity: business volumes
# Entity type: OTHER
# Salience score: 0.0031278394162654877
# Mention text: business volumes
# Mention type: COMMON
# Representative name for the entity: revenues
# Entity type: OTHER
# Salience score: 0.0029632877558469772
# Mention text: revenues
# Mention type: COMMON
# Mention text: revenues
# Mention type: COMMON
# Mention text: revenues
# Mention type: COMMON
# Mention text: revenues
# Mention type: COMMON
# Mention text: revenues
# Mention type: COMMON
# Mention text: revenues
# Mention type: COMMON
# Mention text: revenues
# Mention type: COMMON
# Representative name for the entity: tax
# Entity type: OTHER
# Salience score: 0.0029587442986667156
# Mention text: tax
# Mention type: COMMON
# Representative name for the entity: credit losses
# Entity type: OTHER
# Salience score: 0.0028983226511627436
# Mention text: credit losses
# Mention type: COMMON
# Representative name for the entity: quarter
# Entity type: PERSON
# Salience score: 0.00280267046764493
# Mention text: quarter
# Mention type: COMMON
# Representative name for the entity: RWAs
# Entity type: OTHER
# Salience score: 0.00279818894341588
# mid: /m/07sb389
# wikipedia_url: https://en.wikipedia.org/wiki/Risk-weighted_asset
# Mention text: RWAs
# Mention type: PROPER
# Mention text: RWAs
# Mention type: COMMON
# Mention text: RWAs
# Mention type: PROPER
# Mention text: RWAs
# Mention type: PROPER
# Mention text: RWAs
# Mention type: PROPER
# Representative name for the entity: loans
# Entity type: OTHER
# Salience score: 0.0027687072288244963
# Mention text: loans
# Mention type: COMMON
# Representative name for the entity: financing
# Entity type: OTHER
# Salience score: 0.0027687072288244963
# Mention text: financing
# Mention type: COMMON
# Representative name for the entity: Provision
# Entity type: OTHER
# Salience score: 0.0027687072288244963
# Mention text: Provision
# Mention type: COMMON
# Representative name for the entity: income
# Entity type: OTHER
# Salience score: 0.0027687072288244963
# Mention text: income
# Mention type: COMMON
# Representative name for the entity: target
# Entity type: OTHER
# Salience score: 0.0026987483724951744
# Mention text: target
# Mention type: COMMON
# Representative name for the entity: volumes
# Entity type: OTHER
# Salience score: 0.0026987483724951744
# Mention text: volumes
# Mention type: COMMON
# Representative name for the entity: target
# Entity type: OTHER
# Salience score: 0.0026987483724951744
# Mention text: target
# Mention type: COMMON
# Representative name for the entity: investment volumes
# Entity type: OTHER
# Salience score: 0.0026987483724951744
# Mention text: investment volumes
# Mention type: COMMON
# Representative name for the entity: impact
# Entity type: OTHER
# Salience score: 0.002672528615221381
# Mention text: impact
# Mention type: COMMON
# Mention text: impact
# Mention type: COMMON
# Mention text: impact
# Mention type: COMMON
# Representative name for the entity: RoTE1
# Entity type: OTHER
# Salience score: 0.0026246991474181414
# Mention text: RoTE¹
# Mention type: COMMON
# Representative name for the entity: half
# Entity type: LOCATION
# Salience score: 0.002536018146201968
# Mention text: half
# Mention type: COMMON
# Mention text: half
# Mention type: COMMON
# Representative name for the entity: RoTE1
# Entity type: PERSON
# Salience score: 0.002510346006602049
# Mention text: RoTE1
# Mention type: COMMON
# Mention text: RoTE1
# Mention type: PROPER
# Representative name for the entity: basis points
# Entity type: OTHER
# Salience score: 0.0024615649599581957
# Mention text: basis points
# Mention type: COMMON
# Representative name for the entity: International Private Bank
# Entity type: ORGANIZATION
# Salience score: 0.0023909059818834066
# Mention text: International Private Bank
# Mention type: PROPER
# Mention text: International Private Bank
# Mention type: PROPER
# Mention text: International Private Bank
# Mention type: PROPER
# Representative name for the entity: charges
# Entity type: OTHER
# Salience score: 0.002370570320636034
# Mention text: charges
# Mention type: COMMON
# Representative name for the entity: investment products
# Entity type: OTHER
# Salience score: 0.00227146502584219
# Mention text: investment products
# Mention type: COMMON
# Representative name for the entity: progress
# Entity type: OTHER
# Salience score: 0.00227146502584219
# Mention text: progress
# Mention type: COMMON
# Representative name for the entity: profit
# Entity type: OTHER
# Salience score: 0.0020412474405020475
# Mention text: profit
# Mention type: COMMON
# Representative name for the entity: Record
# Entity type: OTHER
# Salience score: 0.0020397042389959097
# Mention text: Record
# Mention type: COMMON
# Representative name for the entity: inflows
# Entity type: OTHER
# Salience score: 0.0019389491062611341
# Mention text: inflows
# Mention type: COMMON
# Mention text: inflows
# Mention type: COMMON
# Representative name for the entity: measures
# Entity type: OTHER
# Salience score: 0.001899184426292777
# Mention text: measures
# Mention type: COMMON
# Representative name for the entity: measures
# Entity type: OTHER
# Salience score: 0.001899184426292777
# Mention text: measures
# Mention type: COMMON
# Representative name for the entity: path
# Entity type: OTHER
# Salience score: 0.001899184426292777
# Mention text: path
# Mention type: COMMON
# Representative name for the entity: Investment Bank
# Entity type: ORGANIZATION
# Salience score: 0.0017318758182227612
# mid: /m/015p1m
# wikipedia_url: https://en.wikipedia.org/wiki/Investment_banking
# Mention text: Investment Bank
# Mention type: PROPER
# Mention text: Investment Bank
# Mention type: PROPER
# Mention text: Investment Bank
# Mention type: PROPER
# Representative name for the entity: Finance1
# Entity type: OTHER
# Salience score: 0.0016366273630410433
# Mention text: Finance1
# Mention type: PROPER
# Representative name for the entity: businesses
# Entity type: ORGANIZATION
# Salience score: 0.0015922131715342402
# Mention text: businesses
# Mention type: COMMON
# Representative name for the entity: description
# Entity type: OTHER
# Salience score: 0.0015214459272101521
# Mention text: description
# Mention type: COMMON
# Representative name for the entity: Use
# Entity type: OTHER
# Salience score: 0.0015214459272101521
# Mention text: Use
# Mention type: COMMON
# Representative name for the entity: Sustainability
# Entity type: OTHER
# Salience score: 0.0015214459272101521
# Mention text: Sustainability
# Mention type: COMMON
# Representative name for the entity: ambitions
# Entity type: OTHER
# Salience score: 0.0015214459272101521
# Mention text: ambitions
# Mention type: COMMON
# Representative name for the entity: outperformance
# Entity type: OTHER
# Salience score: 0.0015214459272101521
# Mention text: outperformance
# Mention type: COMMON
# Representative name for the entity: expenses
# Entity type: OTHER
# Salience score: 0.0015179708134382963
# Mention text: expenses
# Mention type: COMMON
# Mention text: expenses
# Mention type: COMMON
# Representative name for the entity: revenues
# Entity type: OTHER
# Salience score: 0.001469078240916133
# Mention text: revenues
# Mention type: COMMON
# Representative name for the entity: revenues
# Entity type: OTHER
# Salience score: 0.001469078240916133
# Mention text: revenues
# Mention type: COMMON
# Representative name for the entity: revenues
# Entity type: OTHER
# Salience score: 0.0014264859491959214
# Mention text: revenues
# Mention type: COMMON
# Representative name for the entity: RoTE1
# Entity type: ORGANIZATION
# Salience score: 0.001416157465428114
# Mention text: RoTE1
# Mention type: PROPER
# Mention text: RoTE1
# Mention type: PROPER
# Mention text: RoTE1
# Mention type: PROPER
# Representative name for the entity: Revenues
# Entity type: OTHER
# Salience score: 0.0013413801789283752
# Mention text: Revenues
# Mention type: COMMON
# Representative name for the entity: revenues
# Entity type: OTHER
# Salience score: 0.001316077308729291
# Mention text: revenues
# Mention type: COMMON
# Mention text: revenues
# Mention type: COMMON
# Representative name for the entity: loss
# Entity type: OTHER
# Salience score: 0.0013090779539197683
# Mention text: loss
# Mention type: COMMON
# Representative name for the entity: cost
# Entity type: OTHER
# Salience score: 0.0013085762038826942
# Mention text: cost
# Mention type: COMMON
# Representative name for the entity: loss
# Entity type: OTHER
# Salience score: 0.0013053689617663622
# Mention text: loss
# Mention type: COMMON
# Representative name for the entity: cost
# Entity type: OTHER
# Salience score: 0.001294551300816238
# Mention text: cost
# Mention type: COMMON
# Representative name for the entity: cost
# Entity type: OTHER
# Salience score: 0.0012872498482465744
# Mention text: cost
# Mention type: COMMON
# Representative name for the entity: Christian Sewing
# Entity type: ORGANIZATION
# Salience score: 0.001283822930417955
# wikipedia_url: https://en.wikipedia.org/wiki/Christian_Sewing
# mid: /g/11f5ckrc2p
# Mention text: Christian Sewing
# Mention type: PROPER
# Representative name for the entity: profit
# Entity type: OTHER
# Salience score: 0.00121506885625422
# Mention text: profit
# Mention type: COMMON
# Representative name for the entity: profit
# Entity type: OTHER
# Salience score: 0.0012138811871409416
# Mention text: profit
# Mention type: COMMON
# Representative name for the entity: normalisation
# Entity type: EVENT
# Salience score: 0.0012044142931699753
# Mention text: normalisation
# Mention type: COMMON
# Representative name for the entity: board profit improvement Group profit
# Entity type: OTHER
# Salience score: 0.0011987482430413365
# Mention text: board profit improvement
# Group profit
# Mention type: COMMON
# Representative name for the entity: profit
# Entity type: OTHER
# Salience score: 0.0011933345813304186
# Mention text: profit
# Mention type: COMMON
# Representative name for the entity: cost impact
# Entity type: OTHER
# Salience score: 0.001126350020058453
# Mention text: cost impact
# Mention type: COMMON
# Representative name for the entity: tax
# Entity type: OTHER
# Salience score: 0.0011127032339572906
# Mention text: tax
# Mention type: COMMON
# Representative name for the entity: Bank
# Entity type: ORGANIZATION
# Salience score: 0.0010992554016411304
# Mention text: Bank
# Mention type: COMMON
# Representative name for the entity: tax
# Entity type: OTHER
# Salience score: 0.0010988307185471058
# Mention text: tax
# Mention type: COMMON
# Representative name for the entity: Corporate Banking
# Entity type: ORGANIZATION
# Salience score: 0.0010983222164213657
# Mention text: Corporate Banking
# Mention type: COMMON
# Representative name for the entity: tax
# Entity type: OTHER
# Salience score: 0.0010938680497929454
# Mention text: tax
# Mention type: COMMON
# Representative name for the entity: quarters
# Entity type: OTHER
# Salience score: 0.0010923402151092887
# Mention text: quarters
# Mention type: COMMON
# Representative name for the entity: tax
# Entity type: OTHER
# Salience score: 0.0010910755954682827
# Mention text: tax
# Mention type: COMMON
# Representative name for the entity: risk management
# Entity type: OTHER
# Salience score: 0.001084182527847588
# Mention text: risk management
# Mention type: COMMON
# Representative name for the entity: credit losses
# Entity type: OTHER
# Salience score: 0.0010779278818517923
# Mention text: credit losses
# Mention type: COMMON
# Representative name for the entity: businesses
# Entity type: ORGANIZATION
# Salience score: 0.0010779278818517923
# Mention text: businesses
# Mention type: COMMON
# Representative name for the entity: profit growth
# Entity type: OTHER
# Salience score: 0.0010634212521836162
# Mention text: profit growth
# Mention type: COMMON
# Representative name for the entity: businesses
# Entity type: ORGANIZATION
# Salience score: 0.0010521652875468135
# Mention text: businesses
# Mention type: COMMON
# Representative name for the entity: Unit
# Entity type: ORGANIZATION
# Salience score: 0.0010266515891999006
# Mention text: Unit
# Mention type: COMMON
# Representative name for the entity: Provisions
# Entity type: OTHER
# Salience score: 0.00102353491820395
# Mention text: Provisions
# Mention type: COMMON
# Representative name for the entity: transformation
# Entity type: OTHER
# Salience score: 0.0010071869473904371
# Mention text: transformation
# Mention type: COMMON
# Representative name for the entity: impact
# Entity type: OTHER
# Salience score: 0.0009976456640288234
# Mention text: impact
# Mention type: COMMON
# Representative name for the entity: impact
# Entity type: OTHER
# Salience score: 0.0009967358782887459
# Mention text: impact
# Mention type: COMMON
# Representative name for the entity: litigation expenses
# Entity type: OTHER
# Salience score: 0.0009685363620519638
# Mention text: litigation expenses
# Mention type: COMMON
# Representative name for the entity: revenues
# Entity type: OTHER
# Salience score: 0.0009557836456224322
# Mention text: revenues
# Mention type: COMMON
# Representative name for the entity: relevance
# Entity type: OTHER
# Salience score: 0.00095484679332003
# Mention text: relevance
# Mention type: COMMON
# Representative name for the entity: revenues
# Entity type: OTHER
# Salience score: 0.00095374695956707
# Mention text: revenues
# Mention type: COMMON
# Representative name for the entity: revenues
# Entity type: OTHER
# Salience score: 0.0009524840861558914
# Mention text: revenues
# Mention type: COMMON
# Representative name for the entity: profit improvement
# Entity type: OTHER
# Salience score: 0.0009467334602959454
# Mention text: profit improvement
# Mention type: COMMON
# Representative name for the entity: improvements
# Entity type: OTHER
# Salience score: 0.0009467334602959454
# Mention text: improvements
# Mention type: COMMON
# Representative name for the entity: Revenues
# Entity type: OTHER
# Salience score: 0.0009440891444683075
# Mention text: Revenues
# Mention type: COMMON
# Representative name for the entity: line
# Entity type: OTHER
# Salience score: 0.0009394708904437721
# Mention text: line
# Mention type: COMMON
# Representative name for the entity: cost reduction
# Entity type: OTHER
# Salience score: 0.0009153375867754221
# Mention text: cost reduction
# Mention type: COMMON
# Representative name for the entity: balance sheet management
# Entity type: OTHER
# Salience score: 0.0009085973724722862
# Mention text: balance sheet management
# Mention type: COMMON
# Mention text: decline
# Mention type: COMMON
# Representative name for the entity: bank
# Entity type: ORGANIZATION
# Salience score: 0.0008939344552345574
# Mention text: bank
# Mention type: COMMON
# Representative name for the entity: Revenue development
# Entity type: OTHER
# Salience score: 0.0008920603431761265
# Mention text: Revenue development
# Mention type: COMMON
# Representative name for the entity: development
# Entity type: OTHER
# Salience score: 0.0008892726036719978
# Mention text: development
# Mention type: COMMON
# Representative name for the entity: Leverage Ratio
# Entity type: OTHER
# Salience score: 0.000880550011061132
# Mention text: Leverage Ratio
# Mention type: COMMON
# Representative name for the entity: ruling
# Entity type: OTHER
# Salience score: 0.0008762171491980553
# Mention text: ruling
# Mention type: COMMON
# Representative name for the entity: ruling
# Entity type: OTHER
# Salience score: 0.0008762171491980553
# Mention text: ruling
# Mention type: COMMON
# Representative name for the entity: revenue items
# Entity type: OTHER
# Salience score: 0.0008727136300876737
# Mention text: revenue items
# Mention type: COMMON
# Representative name for the entity: record inflows
# Entity type: OTHER
# Salience score: 0.000872668344527483
# Mention text: record inflows
# Mention type: COMMON
# Representative name for the entity: cost
# Entity type: OTHER
# Salience score: 0.0008665639325045049
# Mention text: cost
# Mention type: COMMON
# Representative name for the entity: cost
# Entity type: OTHER
# Salience score: 0.0008647834765724838
# Mention text: cost
# Mention type: COMMON
# Representative name for the entity: costs
# Entity type: OTHER
# Salience score: 0.000863621651660651
# Mention text: costs
# Mention type: COMMON
# Representative name for the entity: costs
# Entity type: OTHER
# Salience score: 0.000861624488607049
# Mention text: costs
# Mention type: COMMON
# Representative name for the entity: progress
# Entity type: OTHER
# Salience score: 0.0008445869316346943
# Mention text: progress
# Mention type: COMMON
# Representative name for the entity: equity
# Entity type: OTHER
# Salience score: 0.0008412820170633495
# Mention text: equity
# Mention type: COMMON
# Representative name for the entity: loans
# Entity type: OTHER
# Salience score: 0.0008347515831701458
# Mention text: loans
# Mention type: COMMON
# Representative name for the entity: margin
# Entity type: OTHER
# Salience score: 0.0008260682225227356
# Mention text: margin
# Mention type: COMMON
# Representative name for the entity: loan portfolio
# Entity type: OTHER
# Salience score: 0.000824178452603519
# Mention text: loan portfolio
# Mention type: COMMON
# Mention text: loan portfolio
# Mention type: COMMON
# Representative name for the entity: quarters
# Entity type: OTHER
# Salience score: 0.0008187185158021748
# Mention text: quarters
# Mention type: COMMON
# Representative name for the entity: quarters
# Entity type: OTHER
# Salience score: 0.0008187185158021748
# Mention text: quarters
# Mention type: COMMON
# Representative name for the entity: clients
# Entity type: PERSON
# Salience score: 0.0008108124020509422
# Mention text: clients
# Mention type: COMMON
# Representative name for the entity: loss
# Entity type: OTHER
# Salience score: 0.0008095919038169086
# Mention text: loss
# Mention type: COMMON
# Representative name for the entity: profit
# Entity type: OTHER
# Salience score: 0.0008005201816558838
# Mention text: profit
# Mention type: COMMON
# Representative name for the entity: profitability
# Entity type: OTHER
# Salience score: 0.0008000394445843995
# Mention text: profitability
# Mention type: COMMON
# Representative name for the entity: balance
# Entity type: OTHER
# Salience score: 0.0007984022959135473
# Mention text: balance
# Mention type: COMMON
# Representative name for the entity: costs
# Entity type: OTHER
# Salience score: 0.0007937522022984922
# Mention text: costs
# Mention type: COMMON
# Representative name for the entity: deposit re-pricing
# Entity type: OTHER
# Salience score: 0.0007740354049019516
# Mention text: deposit re-pricing
# Mention type: COMMON
# Representative name for the entity: bank
# Entity type: ORGANIZATION
# Salience score: 0.0007693927618674934
# Mention text: bank
# Mention type: COMMON
# Representative name for the entity: bank
# Entity type: ORGANIZATION
# Salience score: 0.0007524983957409859
# Mention text: bank
# Mention type: COMMON
# Representative name for the entity: bank
# Entity type: ORGANIZATION
# Salience score: 0.000752104155253619
# Mention text: bank
# Mention type: COMMON
# Representative name for the entity: bank
# Entity type: ORGANIZATION
# Salience score: 0.0007517262129113078
# Mention text: bank
# Mention type: COMMON
# Representative name for the entity: section
# Entity type: WORK_OF_ART
# Salience score: 0.0007464206428267062
# Mention text: section
# Mention type: COMMON
# Representative name for the entity: tax
# Entity type: OTHER
# Salience score: 0.0007337807328440249
# Mention text: tax
# Mention type: COMMON
# Representative name for the entity: tax
# Entity type: OTHER
# Salience score: 0.0007325190817937255
# Mention text: tax
# Mention type: COMMON
# Representative name for the entity: tax
# Entity type: OTHER
# Salience score: 0.0007310743676498532
# Mention text: tax
# Mention type: COMMON
# Representative name for the entity: tax
# Entity type: OTHER
# Salience score: 0.0007307470659725368
# Mention text: tax
# Mention type: COMMON
# Representative name for the entity: tax
# Entity type: OTHER
# Salience score: 0.0007290022331289947
# Mention text: tax
# Mention type: COMMON
# Representative name for the entity: core businesses
# Entity type: OTHER
# Salience score: 0.0007212773780338466
# Mention text: core businesses
# Mention type: COMMON
# Representative name for the entity: loss
# Entity type: OTHER
# Salience score: 0.0007161248940974474
# Mention text: loss
# Mention type: COMMON
# Representative name for the entity: path
# Entity type: OTHER
# Salience score: 0.0007146412972360849
# Mention text: path
# Mention type: COMMON
# Representative name for the entity: goal
# Entity type: OTHER
# Salience score: 0.0007146412972360849
# Mention text: goal
# Mention type: COMMON
# Representative name for the entity: loss
# Entity type: OTHER
# Salience score: 0.0007140951347537339
# Mention text: loss
# Mention type: COMMON
# Representative name for the entity: market share
# Entity type: OTHER
# Salience score: 0.0007121143862605095
# Mention text: market share
# Mention type: COMMON
# Representative name for the entity: business volumes
# Entity type: OTHER
# Salience score: 0.0007113008759915829
# Mention text: business volumes
# Mention type: COMMON
# Representative name for the entity: business growth
# Entity type: OTHER
# Salience score: 0.0007049081614241004
# Mention text: business growth
# Mention type: COMMON
# Representative name for the entity: growth
# Entity type: EVENT
# Salience score: 0.0007037995383143425
# Mention text: growth
# Mention type: COMMON
# Representative name for the entity: growth
# Entity type: OTHER
# Salience score: 0.0007034597219899297
# Mention text: growth
# Mention type: COMMON
# Representative name for the entity: shareholders
# Entity type: PERSON
# Salience score: 0.0007032995927147567
# Mention text: shareholders
# Mention type: COMMON
# Representative name for the entity: markets
# Entity type: OTHER
# Salience score: 0.0006896250997669995
# Mention text: markets
# Mention type: COMMON
# Representative name for the entity: Emerging Markets
# Entity type: OTHER
# Salience score: 0.0006874697282910347
# Mention text: Emerging Markets
# Mention type: COMMON
# Representative name for the entity: Financing
# Entity type: OTHER
# Salience score: 0.0006872987141832709
# Mention text: Financing
# Mention type: COMMON
# Representative name for the entity: Debt Capital Markets
# Entity type: OTHER
# Salience score: 0.0006869668723084033
# Mention text: Debt Capital Markets
# Mention type: COMMON
# Representative name for the entity: markets
# Entity type: OTHER
# Salience score: 0.0006869668723084033
# Mention text: markets
# Mention type: COMMON
# Representative name for the entity: priority
# Entity type: OTHER
# Salience score: 0.0006826886674389243
# Mention text: priority
# Mention type: COMMON
# Representative name for the entity: end
# Entity type: OTHER
# Salience score: 0.0006823702133260667
# Mention text: end
# Mention type: COMMON
# Representative name for the entity: impact
# Entity type: OTHER
# Salience score: 0.0006721782265231013
# Mention text: impact
# Mention type: COMMON
# Representative name for the entity: impairments
# Entity type: OTHER
# Salience score: 0.0006680698716081679
# Mention text: impairments
# Mention type: COMMON
# Representative name for the entity: target
# Entity type: OTHER
# Salience score: 0.00066738435998559
# Mention text: target
# Mention type: COMMON
# Representative name for the entity: target
# Entity type: OTHER
# Salience score: 0.0006653588498011231
# Mention text: target
# Mention type: COMMON
# Representative name for the entity: Asset Management
# Entity type: OTHER
# Salience score: 0.0006583530339412391
# Mention text: Asset Management
# Mention type: COMMON
# Representative name for the entity: Data Supplement
# Entity type: OTHER
# Salience score: 0.0006550265243276954
# Mention text: Data Supplement
# Mention type: COMMON
# Representative name for the entity: noninterest expenses
# Entity type: OTHER
# Salience score: 0.0006463667959906161
# Mention text: noninterest expenses
# Mention type: COMMON
# Representative name for the entity: execution
# Entity type: OTHER
# Salience score: 0.0006462253513745964
# Mention text: execution
# Mention type: COMMON
# Representative name for the entity: business growth
# Entity type: OTHER
# Salience score: 0.0006447785999625921
# Mention text: business growth
# Mention type: COMMON
# Representative name for the entity: business growth
# Entity type: OTHER
# Salience score: 0.0006441000150516629
# Mention text: business growth
# Mention type: COMMON
# Representative name for the entity: growth
# Entity type: OTHER
# Salience score: 0.0006438441923819482
# Mention text: growth
# Mention type: COMMON
# Representative name for the entity: Growth
# Entity type: OTHER
# Salience score: 0.0006438441923819482
# Mention text: Growth
# Mention type: COMMON
# Representative name for the entity: growth
# Entity type: OTHER
# Salience score: 0.0006435964605771005
# Mention text: growth
# Mention type: COMMON
# Representative name for the entity: information
# Entity type: OTHER
# Salience score: 0.0006401021964848042
# Mention text: information
# Mention type: COMMON
# Representative name for the entity: accounts
# Entity type: OTHER
# Salience score: 0.0006401021964848042
# Mention text: accounts
# Mention type: COMMON
# Representative name for the entity: Interim Report
# Entity type: WORK_OF_ART
# Salience score: 0.0006401021964848042
# Mention text: Interim Report
# Mention type: COMMON
# Representative name for the entity: revenue development
# Entity type: OTHER
# Salience score: 0.0006391658680513501
# Mention text: revenue development
# Mention type: COMMON
# Representative name for the entity: revenues
# Entity type: OTHER
# Salience score: 0.0006377807585522532
# Mention text: revenues
# Mention type: COMMON
# Mention text: revenues
# Mention type: COMMON
# Representative name for the entity: levels
# Entity type: OTHER
# Salience score: 0.0006316228536888957
# Mention text: levels
# Mention type: COMMON
# Representative name for the entity: improvement
# Entity type: OTHER
# Salience score: 0.0006308978190645576
# Mention text: improvement
# Mention type: COMMON
# Representative name for the entity: client loans
# Entity type: OTHER
# Salience score: 0.0006295238272286952
# Mention text: client loans
# Mention type: COMMON
# Representative name for the entity: assets
# Entity type: OTHER
# Salience score: 0.000628626614343375
# Mention text: assets
# Mention type: COMMON
# Representative name for the entity: improvement
# Entity type: OTHER
# Salience score: 0.0006283953553065658
# Mention text: improvement
# Mention type: COMMON
# Representative name for the entity: litigation provisions
# Entity type: OTHER
# Salience score: 0.000628272129688412
# Mention text: litigation provisions
# Mention type: COMMON
# Representative name for the entity: improvement
# Entity type: OTHER
# Salience score: 0.0006281330715864897
# Mention text: improvement
# Mention type: COMMON
# Representative name for the entity: leverage
# Entity type: OTHER
# Salience score: 0.0006278795190155506
# Mention text: leverage
# Mention type: COMMON
# Representative name for the entity: Unit
# Entity type: ORGANIZATION
# Salience score: 0.0006276341155171394
# Mention text: Unit
# Mention type: COMMON
# Representative name for the entity: improvement
# Entity type: OTHER
# Salience score: 0.0006269419682212174
# Mention text: improvement
# Mention type: COMMON
# Representative name for the entity: improvement
# Entity type: OTHER
# Salience score: 0.0006267245044000447
# Mention text: improvement
# Mention type: COMMON
# Representative name for the entity: effects
# Entity type: OTHER
# Salience score: 0.000613237323705107
# Mention text: effects
# Mention type: COMMON
# Representative name for the entity: business volumes
# Entity type: OTHER
# Salience score: 0.000613084645010531
# Mention text: business volumes
# Mention type: COMMON
# Representative name for the entity: currency translation effects
# Entity type: OTHER
# Salience score: 0.0006122809718362987
# Mention text: currency translation effects
# Mention type: COMMON
# Representative name for the entity: effects
# Entity type: OTHER
# Salience score: 0.000611930328886956
# Mention text: effects
# Mention type: COMMON
# Representative name for the entity: loss reduction
# Entity type: OTHER
# Salience score: 0.0006080872262828052
# Mention text: loss reduction
# Mention type: COMMON
# Representative name for the entity: cost reduction
# Entity type: OTHER
# ...
# Mention text: Oracle Database
# Mention type: PROPER
# Representative name for the entity: services
# Entity type: OTHER
# Salience score: 0.0033096761908382177
# Mention text: services
# Mention type: COMMON
# Representative name for the entity: cloud
# Entity type: OTHER
# Salience score: 0.0032180931884795427
# Mention text: cloud
# Mention type: COMMON
# Representative name for the entity: Exadata Cloud Service
# Entity type: OTHER
# Salience score: 0.0031536773312836885
# Mention text: Exadata Cloud Service
# Mention type: PROPER
# Representative name for the entity: Frankfurt
# Entity type: LOCATION
# Salience score: 0.0031390050426125526
# wikipedia_url: https://en.wikipedia.org/wiki/Frankfurt
# mid: /m/02z0j
# Mention text: Frankfurt
# Mention type: PROPER
# Representative name for the entity: data security technologies
# Entity type: OTHER
# Salience score: 0.0031375244725495577
# Mention text: data security technologies
# Mention type: COMMON
# Representative name for the entity: technology
# Entity type: OTHER
# Salience score: 0.0031375244725495577
# Mention text: technology
# Mention type: COMMON
# Representative name for the entity: Technology
# Entity type: OTHER
# Salience score: 0.003133461344987154
# Mention text: Technology
# Mention type: COMMON
# Representative name for the entity: bulk
# Entity type: OTHER
# Salience score: 0.002931848866865039
# Mention text: bulk
# Mention type: COMMON
# Representative name for the entity: estate
# Entity type: LOCATION
# Salience score: 0.002931848866865039
# Mention text: estate
# Mention type: COMMON
# Representative name for the entity: applications
# Entity type: OTHER
# Salience score: 0.002825781935825944
# Mention text: applications
# Mention type: COMMON
# Representative name for the entity: applications
# Entity type: OTHER
# Salience score: 0.0028211441822350025
# Mention text: applications
# Mention type: COMMON
# Representative name for the entity: innovation partnership
# Entity type: OTHER
# Salience score: 0.0028170598670840263
# Mention text: innovation partnership
# Mention type: COMMON
# Representative name for the entity: bank
# Entity type: ORGANIZATION
# Salience score: 0.0027983698528259993
# Mention text: bank
# Mention type: COMMON
# Representative name for the entity: applications
# Entity type: OTHER
# Salience score: 0.002796533051878214
# Mention text: applications
# Mention type: COMMON
# Representative name for the entity: collaboration
# Entity type: OTHER
# Salience score: 0.002693457994610071
# Mention text: collaboration
# Mention type: COMMON
# Representative name for the entity: services
# Entity type: OTHER
# Salience score: 0.0024806151632219553
# Mention text: services
# Mention type: COMMON
# Representative name for the entity: servers
# Entity type: OTHER
# Salience score: 0.0024785103742033243
# Mention text: servers
# Mention type: COMMON
# Representative name for the entity: service processes
# Entity type: OTHER
# Salience score: 0.0024780097883194685
# Mention text: service processes
# Mention type: COMMON
# Representative name for the entity: systems
# Entity type: OTHER
# Salience score: 0.0024619046598672867
# Mention text: systems
# Mention type: COMMON
# Representative name for the entity: payments processing
# Entity type: OTHER
# Salience score: 0.0024619046598672867
# Mention text: payments processing
# Mention type: COMMON
# Representative name for the entity: systems
# Entity type: OTHER
# Salience score: 0.002456388436257839
# Mention text: systems
# Mention type: COMMON
# Representative name for the entity: platform
# Entity type: OTHER
# Salience score: 0.002456388436257839
# Mention text: platform
# Mention type: COMMON
# Representative name for the entity: technologies
# Entity type: OTHER
# Salience score: 0.0023476758506149054
# Mention text: technologies
# Mention type: COMMON
# Representative name for the entity: step
# Entity type: OTHER
# Salience score: 0.002323152730241418
# Mention text: step
# Mention type: COMMON
# Representative name for the entity: transformation
# Entity type: OTHER
# Salience score: 0.0022672913037240505
# Mention text: transformation
# Mention type: COMMON
# Representative name for the entity: business
# Entity type: OTHER
# Salience score: 0.0022601443342864513
# Mention text: business
# Mention type: COMMON
# Representative name for the entity: operations
# Entity type: OTHER
# Salience score: 0.0022601443342864513
# Mention text: operations
# Mention type: COMMON
# Representative name for the entity: companies
# Entity type: ORGANIZATION
# Salience score: 0.002256871433928609
# Mention text: companies
# Mention type: COMMON
# Representative name for the entity: data residency requirements
# Entity type: OTHER
# Salience score: 0.002240421948954463
# Mention text: data residency requirements
# Mention type: COMMON
# Representative name for the entity: costs
# Entity type: OTHER
# Salience score: 0.002240421948954463
# Mention text: costs
# Mention type: COMMON
# Representative name for the entity: data centers
# Entity type: LOCATION
# Salience score: 0.0022361765149980783
# Mention text: data centers
# Mention type: COMMON
# Representative name for the entity: cloud co-location sites
# Entity type: LOCATION
# Salience score: 0.0019884412176907063
# Mention text: cloud co-location sites
# Mention type: COMMON
# Representative name for the entity: latency
# Entity type: OTHER
# Salience score: 0.0019884412176907063
# Mention text: latency
# Mention type: COMMON
# Representative name for the entity: shift
# Entity type: OTHER
# Salience score: 0.0019884412176907063
# Mention text: shift
# Mention type: COMMON
# Representative name for the entity: order
# Entity type: OTHER
# Salience score: 0.0019851764664053917
# Mention text: order
# Mention type: COMMON
# Representative name for the entity: implementations
# Entity type: OTHER
# Salience score: 0.0019851764664053917
# Mention text: implementations
# Mention type: COMMON
# Representative name for the entity: data integration
# Entity type: OTHER
# Salience score: 0.0019851764664053917
# Mention text: data integration
# Mention type: COMMON
# Representative name for the entity: customer demand
# Entity type: OTHER
# Salience score: 0.0019851764664053917
# Mention text: customer demand
# Mention type: COMMON
# Representative name for the entity: planning
# Entity type: OTHER
# Salience score: 0.001972271129488945
# Mention text: planning
# Mention type: COMMON
# Representative name for the entity: capital
# Entity type: OTHER
# Salience score: 0.001972271129488945
# Mention text: capital
# Mention type: COMMON
# Representative name for the entity: reporting
# Entity type: OTHER
# Salience score: 0.001972271129488945
# Mention text: reporting
# Mention type: COMMON
# Representative name for the entity: risk
# Entity type: OTHER
# Salience score: 0.001972271129488945
# Mention text: risk
# Mention type: COMMON
# Representative name for the entity: platform
# Entity type: OTHER
# Salience score: 0.001878041191957891
# Mention text: platform
# Mention type: COMMON
# Representative name for the entity: analytics
# Entity type: OTHER
# Salience score: 0.0018186847446486354
# Mention text: analytics
# Mention type: COMMON
# Representative name for the entity: design
# Entity type: OTHER
# Salience score: 0.0018186847446486354
# Mention text: design
# Mention type: COMMON
# Representative name for the entity: uses
# Entity type: OTHER
# Salience score: 0.0018186847446486354
# Mention text: uses
# Mention type: COMMON
# Representative name for the entity: engineering
# Entity type: OTHER
# Salience score: 0.0018186847446486354
# Mention text: engineering
# Mention type: COMMON
# Representative name for the entity: AI
# Entity type: OTHER
# Salience score: 0.0018186847446486354
# Mention text: AI
# Mention type: COMMON
# Representative name for the entity: blockchain
# Entity type: OTHER
# Salience score: 0.0018186847446486354
# Mention text: blockchain
# Mention type: COMMON
# Representative name for the entity: cloud strategy
# Entity type: OTHER
# Salience score: 0.001816328032873571
# Mention text: cloud strategy
# Mention type: COMMON
# Representative name for the entity: initiative
# Entity type: OTHER
# Salience score: 0.001816328032873571
# Mention text: initiative
# Mention type: COMMON
# Representative name for the entity: division
# Entity type: ORGANIZATION
# Salience score: 0.001816328032873571
# Mention text: division
# Mention type: COMMON
# Representative name for the entity: platform
# Entity type: OTHER
# Salience score: 0.0017013263422995806
# Mention text: platform
# Mention type: COMMON
# Representative name for the entity: process
# Entity type: OTHER
# Salience score: 0.0016998822102323174
# Mention text: process
# Mention type: COMMON
# Representative name for the entity: agreement
# Entity type: OTHER
# Salience score: 0.001644320203922689
# Mention text: agreement
# Mention type: COMMON
# Representative name for the entity: Data and Innovation
# Entity type: OTHER
# Salience score: 0.0016027337405830622
# Mention text: Data and Innovation
# Mention type: PROPER
# Representative name for the entity: teams
# Entity type: ORGANIZATION
# Salience score: 0.0015689730644226074
# Mention text: teams
# Mention type: COMMON
# Representative name for the entity: speed
# Entity type: OTHER
# Salience score: 0.0015516935382038355
# Mention text: speed
# Mention type: COMMON
# Representative name for the entity: technology environment
# Entity type: OTHER
# Salience score: 0.0015503762988373637
# Mention text: technology environment
# Mention type: COMMON
# Representative name for the entity: costs
# Entity type: OTHER
# Salience score: 0.0015503762988373637
# Mention text: costs
# Mention type: COMMON
# Representative name for the entity: speed-of-innovation
# Entity type: OTHER
# Salience score: 0.0015491452068090439
# Mention text: speed-of-innovation
# Mention type: COMMON
# Representative name for the entity: oversight
# Entity type: OTHER
# Salience score: 0.0015142878983169794
# Mention text: oversight
# Mention type: COMMON
# Representative name for the entity: Data
# Entity type: OTHER
# Salience score: 0.0014544111909344792
# Mention text: Data
# Mention type: COMMON
# Representative name for the entity: innovators
# Entity type: OTHER
# Salience score: 0.001420715358108282
# Mention text: innovators
# Mention type: COMMON
# Representative name for the entity: needs
# Entity type: OTHER
# Salience score: 0.0013823570916429162
# Mention text: needs
# Mention type: COMMON
# Representative name for the entity: flexibility
# Entity type: OTHER
# Salience score: 0.0013628564774990082
# Mention text: flexibility
# Mention type: COMMON
# Representative name for the entity: data insights
# Entity type: OTHER
# Salience score: 0.0013628564774990082
# Mention text: data insights
# Mention type: COMMON
# Representative name for the entity: energy consumption
# Entity type: OTHER
# Salience score: 0.001361699542030692
# Mention text: energy consumption
# Mention type: COMMON
# Representative name for the entity: trading
# Entity type: OTHER
# Salience score: 0.0013139237416908145
# Mention text: trading
# Mention type: COMMON
# Representative name for the entity: Data
# Entity type: OTHER
# Salience score: 0.0012080010492354631
# Mention text: Data
# Mention type: COMMON
# Representative name for the entity: databases
# Entity type: OTHER
# Salience score: 0.0012080010492354631
# Mention text: databases
# Mention type: COMMON
# Representative name for the entity: services
# Entity type: OTHER
# Salience score: 0.0010895763989537954
# Mention text: services
# Mention type: COMMON
# Representative name for the entity: environment
# Entity type: OTHER
# Salience score: 0.0010840578470379114
# Mention text: environment
# Mention type: COMMON
# Representative name for the entity: requirements
# Entity type: OTHER
# Salience score: 0.0010840578470379114
# Mention text: requirements
# Mention type: COMMON
# Representative name for the entity: data security
# Entity type: OTHER
# Salience score: 0.0010840578470379114
# Mention text: data security
# Mention type: COMMON
# Representative name for the entity: business models
# Entity type: CONSUMER_GOOD
# Salience score: 0.0010832489933818579
# Mention text: business models
# Mention type: COMMON
# Representative name for the entity: one
# Entity type: OTHER
# Salience score: 0.0010832489933818579
# Mention text: one
# Mention type: COMMON
# Representative name for the entity: TDI
# Entity type: ORGANIZATION
# Salience score: 0.0010733157396316528
# Mention text: TDI
# Mention type: PROPER
# Representative name for the entity: Chief Technology
# Entity type: ORGANIZATION
# Salience score: 0.001031825435347855
# Mention text: Chief Technology
# Mention type: COMMON
# Representative name for the entity: Mission-Critical Database Technologies
# Entity type: ORGANIZATION
# Salience score: 0.0009701616945676506
# Mention text: Mission-Critical Database Technologies
# Mention type: PROPER
# Representative name for the entity: locality
# Entity type: OTHER
# Salience score: 0.0009521037572994828
# Mention text: locality
# Mention type: COMMON
# Representative name for the entity: generation
# Entity type: OTHER
# Salience score: 0.0009513933910056949
# Mention text: generation
# Mention type: COMMON
# Representative name for the entity: Executive Vice President
# Entity type: PERSON
# Salience score: 0.0009513933910056949
# Mention text: Executive Vice President
# Mention type: COMMON
# Representative name for the entity: balance
# Entity type: OTHER
# Salience score: 0.0009513933910056949
# Mention text: balance
# Mention type: COMMON
# Representative name for the entity: sector
# Entity type: OTHER
# Salience score: 0.0009513933910056949
# Mention text: sector
# Mention type: COMMON
# Representative name for the entity: applications
# Entity type: OTHER
# Salience score: 0.000849065138027072
# Mention text: applications
# Mention type: COMMON
# Representative name for the entity: partnership
# Entity type: OTHER
# Salience score: 0.0008007431752048433
# Mention text: partnership
# Mention type: COMMON
# Representative name for the entity: products
# Entity type: CONSUMER_GOOD
# Salience score: 0.0007471210556104779
# Mention text: products
# Mention type: COMMON
# Representative name for the entity: technology transformation
# Entity type: OTHER
# Salience score: 0.000746385077945888
# Mention text: technology transformation
# Mention type: COMMON
# Representative name for the entity: collaboration
# Entity type: OTHER
# Salience score: 0.0007193161291070282
# Mention text: collaboration
# Mention type: COMMON
# Representative name for the entity: operations
# Entity type: OTHER
# Salience score: 0.0006813826621510088
# Mention text: operations
# Mention type: COMMON
# Representative name for the entity: customers
# Entity type: PERSON
# Salience score: 0.0006813826621510088
# Mention text: customers
# Mention type: COMMON
# Representative name for the entity: Innovation Officer
# Entity type: PERSON
# Salience score: 0.0005978389526717365
# Mention text: Innovation Officer
# Mention type: COMMON
# Representative name for the entity: Juan Loaiza
# Entity type: PERSON
# Salience score: 0.000522068003192544
# Mention text: Juan Loaiza
# Mention type: PROPER
# Representative name for the entity: Bernd Leukert
# Entity type: PERSON
# Salience score: 0.0003280322707723826
# wikipedia_url: https://de.wikipedia.org/wiki/Bernd_Leukert
# mid: /g/11fy1t_1kz
# Mention text: Bernd Leukert
# Mention type: PROPER
# Representative name for the entity: role
# Entity type: OTHER
# Salience score: 0.00029266386991366744
# Mention text: role
# Mention type: COMMON
# Representative name for the entity: June 24, 2021
# Entity type: DATE
# Salience score: 0.0
# day: 24
# year: 2021
# month: 6
# Mention text: June 24, 2021
# Mention type: TYPE_UNKNOWN
# Representative name for the entity: December 2020
# Entity type: DATE
# Salience score: 0.0
# month: 12
# year: 2020
# Mention text: December 2020
# Mention type: TYPE_UNKNOWN
# Representative name for the entity: one
# Entity type: NUMBER
# Salience score: 0.0
# value: 1
# Mention text: one
# Mention type: TYPE_UNKNOWN
# Representative name for the entity: 24
# Entity type: NUMBER
# Salience score: 0.0
# value: 24
# Mention text: 24
# Mention type: TYPE_UNKNOWN
# Representative name for the entity: two
# Entity type: NUMBER
# Salience score: 0.0
# value: 2
# Mention text: two
# Mention type: TYPE_UNKNOWN
# Representative name for the entity: 2021
# Entity type: NUMBER
# Salience score: 0.0
# value: 2021
# Mention text: 2021
# Mention type: TYPE_UNKNOWN
# Representative name for the entity: 2020
# Entity type: NUMBER
# Salience score: 0.0
# value: 2020
# Mention text: 2020
# Mention type: TYPE_UNKNOWN
# Representative name for the entity: one
# Entity type: NUMBER
# Salience score: 0.0
# value: 1
# Mention text: one
# Mention type: TYPE_UNKNOWN
# Language of the text: en

# %%
print(arcText)
response = os.exec('curl -X 'POST' \
  'https://dbgee-mar22-12.ew.r.appspot.com/api/text' \
  -H 'accept: application/json' \
  -H 'Content-Type: application/x-www-form-urlencoded' \
  -d 'text=buy%20flowers%20for%20the%20weekend%20cos%20it'\''s%20mother'\''s%20day'')
# Out:
#   File "/tmp/ipykernel_13647/374554267.py", line 2
#     response = os.exec('curl -X 'POST' \
#                                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# To gain more insight into a particular column, you can use the *describe()* method on the dataframe column name.

# %%
# describe the monthly rainfall
rain_data = weather.Rain.describe()
print(rain_data)

# %% [markdown]
# #### 1D Line Graph

# %%
# plot max temp. vs month

max_temp_fig = px.line(weather, x='Month', y='Tmax')
max_temp_fig.show()


# you can compare this to the following line of code, which uses the more standard matplotlib library to plot the same data

weather.plot.line(y='Tmax', x='Month')

# %% [markdown]
# We can plot multiple lines on the same graph and edit the layout to make it look more sophisticated. We can also update the dataframe with the average temperature and show that on the graph too.

# %%
# calculate ave. temp. and create a new column in the dataframe 
weather['Tmed'] = (weather['Tmax'] + weather['Tmin'])/2

# inspect the first 5 rows
weather.head()

# %%
# plot max and min temp. vs month
min_temp = go.Scatter(x=weather['Month'], y=weather['Tmin'], name='Min Temp')
med_temp = go.Scatter(x=weather['Month'], y=weather['Tmed'], name='Ave Temp')
max_temp = go.Scatter(x=weather['Month'], y=weather['Tmax'], name='Max Temp')

min_max_temp_fig = go.Figure()

min_max_temp_fig.add_trace(min_temp)
min_max_temp_fig.add_trace(med_temp)
min_max_temp_fig.add_trace(max_temp)

# edit the layout
min_max_temp_fig.update_layout(title="Temperature Distribution",
                               xaxis_title='Month',
                               yaxis_title='Temperature (Celsius)')

min_max_temp_fig.show()

# %% [markdown]
# #### Bar Chart

# %%
# lot rainfall vs month

rainfall_fig = px.bar(weather, x='Month', y='Rain')
rainfall_fig.update_layout(title="Rainfall Distribution",
                           xaxis_title="Month",
                           yaxis_title='Rain')
rainfall_fig.show()

# The following line of code achieves the same thing using Matplotlib

# weather.plot.bar(y='Rain', x='Month')

# %% [markdown]
# #### Histogram
#
# Histograms are useful for when you want to visualise the frequency distribution of the data.

# %%
rainfall_hist = px.histogram(weather, x='Rain', nbins=10) # you can specify the number of bins
rainfall_hist.update_layout(title="Frequency of Rainfall Amount",
                            bargap=0.1) # you can specify a gap between bars
rainfall_hist.show()

# %% [markdown]
# #### Multiple Charts
#
# You can also create separate charts for each column of data. The following example shows separate line graphs of the four columns.

# %%
# multiple line charts 
rain = go.Scatter(x=weather['Month'], y=weather['Rain'], name="Rain")
sun = go.Scatter(x=weather['Month'], y=weather['Sun'], name="Sun")

subplots_fig = make_subplots(rows=2, cols=2,
                             subplot_titles=("Min Temp", "Max Temp", "Rain", "Sun"))

# use min_temp and max_temp plots from before
subplots_fig.add_trace(min_temp, row=1, col=1)
subplots_fig.add_trace(max_temp, row=2, col=1)
subplots_fig.add_trace(rain, row=1, col=2)
subplots_fig.add_trace(sun, row=2, col=2)

subplots_fig.update_layout(height=600, width=800, title_text="Subplots Demo")

subplots_fig.show()

# %% [markdown]
# ## Introducing Jupyter Dash
#
# Dash is Plotly's open source Python framework for building full stack analytic web applications using pure Python. The JupyterDash library makes these features available from the jupyter notebook.

# %%
### Run ngrok to tunnel Dash app port 8050 to the outside world. 
### This command runs in the background.
get_ipython().system_raw('./ngrok http 8050 &')

# %%
# get ID of the most recent 
last_text_id = list(data.keys())[0]

app = JupyterDash(__name__)

app.layout = html.Div([
    html.H1("JupyterDash Demo"),
    
    
    # THESE LINES DISPLAY THE OUTPUT OF NLP API
    html.P("Most Recent Text ID: {}".format(last_text_id)),
    html.P("Text Analysed: {}".format(data[last_text_id]["text"])),
    html.P("Sentiment: {}".format(data[last_text_id]["sentiment"])),
  
    # THESE LINES DEMO ONE OF THE DASH CORE COMPONENT(dcc) i.e. dcc.Input
    html.H3("Change the value in the text box to see callbacks in action!"),
    html.Div([
        "Input: ",
        dcc.Input(id='my-input', value='initial value', type='text')
    ]),
    html.Br(),
    html.Div(id='my-output'),
    
    # THESE LINES DEMO THE INTEGRATION OF PLOTLY GRAPHS WITH DASH
    dcc.Graph(figure=subplots_fig),

])


@app.callback(
    Output(component_id='my-output', component_property='children'),
    Input(component_id='my-input', component_property='value')
)
def update_output_div(input_value):
    return 'Output: {}'.format(input_value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13647/3987709544.py in <module>
#      23
#      24     # THESE LINES DEMO THE INTEGRATION OF PLOTLY GRAPHS WITH DASH
# ---> 25     dcc.Graph(figure=subplots_fig),
#      26
#      27 ])
#
# NameError: name 'subplots_fig' is not defined

# %%
app.run_server(mode="external", port=8049)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_13647/306444106.py in <module>
# ----> 1 app.run_server(mode="external", port=8049)
#
# ~/.local/lib/python3.7/site-packages/jupyter_dash/jupyter_app.py in run_server(self, mode, width, height, inline_exceptions, **kwargs)
#     320                 )
#     321
# --> 322         wait_for_app()
#     323
#     324         if JupyterDash._in_colab:
#
# /opt/conda/lib/python3.7/site-packages/retrying.py in wrapped_f(*args, **kw)
#      47             @six.wraps(f)
#      48             def wrapped_f(*args, **kw):
# ---> 49                 return Retrying(*dargs, **dkw).call(f, *args, **kw)
#      50
#      51             return wrapped_f
#
# /opt/conda/lib/python3.7/site-packages/retrying.py in call(self, fn, *args, **kwargs)
#     210                 if not self._wrap_exception and attempt.has_exception:
#     211                     # get() on an attempt with an exception should cause it to be raised, but raise just in case
# --> 212                     raise attempt.get()
#     213                 else:
#     214                     raise RetryError(attempt)
#
# /opt/conda/lib/python3.7/site-packages/retrying.py in get(self, wrap_exception)
#     245                 raise RetryError(self)
#     246             else:
# --> 247                 six.reraise(self.value[0], self.value[1], self.value[2])
#     248         else:
#     249             return self.value
#
# /opt/conda/lib/python3.7/site-packages/six.py in reraise(tp, value, tb)
#     717             if value.__traceback__ is not tb:
#     718                 raise value.with_traceback(tb)
# --> 719             raise value
#     720         finally:
#     721             value = None
#
# /opt/conda/lib/python3.7/site-packages/retrying.py in call(self, fn, *args, **kwargs)
#     198         while True:
#     199             try:
# --> 200                 attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     201             except:
#     202                 tb = sys.exc_info()
#
# ~/.local/lib/python3.7/site-packages/jupyter_dash/jupyter_app.py in wait_for_app()
#     316                     "Address '{url}' already in use.\n"
#     317                     "    Try passing a different port to run_server.".format(
# --> 318                         url=url
#     319                     )
#     320                 )
#
# OSError: Address 'http://127.0.0.1:8049' already in use.
#     Try passing a different port to run_server.

# %% [markdown]
# #### In case the below cell has errors, please rerun it

# %%
### Get the public URL where you can access the Dash app. Copy this URL.
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# https://36bd-35-246-61-166.ngrok.io
